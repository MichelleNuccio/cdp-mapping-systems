# %% [markdown]
# In this exercise, we will explore networks and distance. We will start by using an abstract network of points and lines to illustrate some concepts, and then move on to using real-world data to identify proximate objects based on network distance.

# %% [markdown]
# ## Import libraries

# %%
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import LineString, MultiLineString, Point, Polygon
import pandas as pd
import requests
import networkx as nx
import osmnx as ox
import h3
import libpysal as lps
import numpy as np

# %% [markdown]
# We'll import our helper library and update the graph output just like in the previous tutorial.

# %%
from cdptools import utils

# %%
utils.set_axis_off()

# %% [markdown]
# To begin, we will find the approximate bounding box of NYC.

# %%
# bounding box of nyc
bbox = (-74.3, 40.5, -73.7, 40.9)

# %% [markdown]
# ## Create random network

# %% [markdown]
# We'll begin by creating a dataframe of 100 random points. As we can see below, we are using `numpy` to generate random numbers, along with geopandas' `points_from_xy()` to create a geodataframe from these points. We are using the bounds of NYC to make sure that the network approximately covers the city.

# %%
# create a geodataframe of 100 random points
np.random.seed(0)
n = 100
df = pd.DataFrame(
    {
        "geometry": gpd.points_from_xy(
            np.random.uniform(-74.3, -73.7, n),
            np.random.uniform(40.5, 40.9, n),
        ),
    }
)

# %% [markdown]
# And here we cast the dataframe as a geodataframe and set its CRS.

# %%
gdf = gpd.GeoDataFrame(df, crs="EPSG:4326")

# %% [markdown]
# As we can see from our initial plot, we have a mass of 100 randomly distributed points. At this stage, this is meaningless!

# %%
gdf.plot()
# Out:
# <Axes: >

# %% [markdown]
# Since we are creating a network (instead of analyzing an already existing one), let's connect each node to its five nearest neighbors (measured based on straight-line or *Euclidean* distance). We'll use geopandas' `distance` method to calculate the distance between each pair of points, and then use that to create a list of edges. There are many ways to calculate distance like this, some of which are more appropriate for working with a greater volume of data (`scipy`'s [KDTree](https://docs.scipy.org/doc/scipy/reference/generated/scipy.spatial.KDTree.html) operations chief among them).
#
# We can also ignore the warning about the geographic CRS as well given our use case and scale, but do keep in mind that projection-related considerations are extremely important when calculating distances.

# %%
# find five nearest neighbors for each point, not including itself
k = 5
neighbors = gdf.geometry.apply(lambda x: gdf.geometry.distance(x)).values.argsort(
    axis=1
)[:, 1 : k + 1]

# join neighbors to original dataframe
gdf["neighbors"] = neighbors.tolist()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_36368\2007509322.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'distance' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   neighbors = gdf.geometry.apply(lambda x: gdf.geometry.distance(x)).values.argsort(

# %%
gdf.neighbors
# Out:
# 0      [12, 28, 88, 2, 37]
# 1     [83, 91, 42, 39, 31]
# 2      [88, 12, 62, 37, 0]
# 3     [84, 11, 22, 51, 56]
# 4     [29, 41, 32, 58, 80]
#               ...
# 95    [61, 24, 57, 87, 15]
# 96     [33, 50, 91, 83, 1]
# 97    [75, 69, 67, 15, 92]
# 98      [66, 8, 52, 72, 1]
# 99    [15, 34, 67, 61, 82]
# Name: neighbors, Length: 100, dtype: object

# %% [markdown]
# Now if we inspect our dataframe, we see that we have an additional column, `neighbors`, which contains the row index number of the five nearest points to that row.

# %%
gdf.head(5)
# Out:
#                      geometry             neighbors
# 0  POINT (-73.97071 40.77113)   [12, 28, 88, 2, 37]
# 1    POINT (-73.87089 40.608)  [83, 91, 42, 39, 31]
# 2  POINT (-73.93834 40.79408)   [88, 12, 62, 37, 0]
# 3  POINT (-73.97307 40.88488)  [84, 11, 22, 51, 56]
# 4   POINT (-74.04581 40.5995)  [29, 41, 32, 58, 80]

# %% [markdown]
# Based on that information, we can now draw *lines* (or network *edges*) between each point and its nearest neighbors. We can use the following function to create an array of lines between a point and it's neighbors.
#
# Let's consider the component parts of the function:
# - `lines = []`: we create an empty array to store line geometry in
# - `for i, neighbor in enumerage(r.neighbors)`: we set up a `for` loop to iterate through each row's list of point indexes
# - `lines.append(LineString([r.geometry, gdf.loc[neighbor].geometry]))`: we create a new `LineString` geometry with two points: the starting point at the input row `r.geometry`, and ending at the looked up neighbor's geometry `gdf.loc[neighbor].geometry`. The `.loc[neighbor]` allows us to find the row that matches based on the neighbor `id`, and then we access its `geometry` property
# - `return MultiLineString(lines)`: we combine each of the line geometries in the `lines` array into one complex `MultiLineString`, which is what it sounds like (a combination of `LineStrings`).

# %%
def create_lines(r):
    lines = []
    for i, neighbor in enumerate(r.neighbors):
        lines.append(LineString([r.geometry, gdf.loc[neighbor].geometry]))
    return MultiLineString(lines)

# %% [markdown]
# We can then apply the function to each row (`axis=1`). Keep in mind that when executing a function via `apply()`, the row (or column) input is implied and is the default input `r` in the function.

# %%
gdf["line_geometry"] = gdf.apply(create_lines, axis=1)

# %% [markdown]
# If we inspect our dataframe again, we'll see a new column `line_geometry` which represents the edges between each point and its five nearest neighbors.

# %%
gdf.head()
# Out:
#                      geometry             neighbors  \
# 0  POINT (-73.97071 40.77113)   [12, 28, 88, 2, 37]
# 1    POINT (-73.87089 40.608)  [83, 91, 42, 39, 31]
# 2  POINT (-73.93834 40.79408)   [88, 12, 62, 37, 0]
# 3  POINT (-73.97307 40.88488)  [84, 11, 22, 51, 56]
# 4   POINT (-74.04581 40.5995)  [29, 41, 32, 58, 80]
#
#                                        line_geometry
# 0  MULTILINESTRING ((-73.97071 40.77113, -73.9591...
# 1  MULTILINESTRING ((-73.87089 40.608, -73.88452 ...
# 2  MULTILINESTRING ((-73.93834 40.79408, -73.9544...
# 3  MULTILINESTRING ((-73.97307 40.88488, -73.9600...
# 4  MULTILINESTRING ((-74.04581 40.5995, -74.0512 ...

# %% [markdown]
# We can create a new geodataframe based on this edges geometry and plot it- now we have a connected network of points and lines!

# %%
lines_gdf = gpd.GeoDataFrame(
    gdf[["line_geometry"]], geometry="line_geometry", crs="EPSG:4326"
)

# %%
ax = lines_gdf.plot(color="black", alpha=0.5, linewidth=0.2)
gdf.plot(ax=ax, color="black")

# optionally save the figure to file
# plt.savefig("lines.pdf", bbox_inches="tight", pad_inches=0)
# Out:
# <Axes: >

# %% [markdown]
# ### Saving our datasets

# %% [markdown]
# You may optionally want to save these nodes and edges to file to inspect in QGIS or another software. To do so, we use the `to_file()` function to save out as GeoJSON files

# %%
gdf["geometry"].to_file("nodes.geojson", driver="GeoJSON")
gdf["line_geometry"].to_file("edges.geojson", driver="GeoJSON")
# Out:
# c:\Users\ASUS\anaconda3\envs\cdp\Lib\site-packages\pyogrio\geopandas.py:917: UserWarning: 'crs' was not provided.  The output dataset will not have projection information defined and may not be usable in other systems.
#   write(

# %%
gdf.sample(10)
# Out:
#                       geometry             neighbors  \
# 91  POINT (-73.89955 40.58394)   [83, 1, 96, 50, 33]
# 29   POINT (-74.0512 40.61603)   [4, 41, 58, 32, 90]
# 2   POINT (-73.93834 40.79408)   [88, 12, 62, 37, 0]
# 50  POINT (-73.95788 40.55978)  [96, 73, 33, 91, 32]
# 44  POINT (-73.89994 40.82248)   [56, 62, 45, 74, 2]
# 78  POINT (-74.12232 40.78177)  [48, 94, 30, 85, 57]
# 33  POINT (-73.95894 40.61931)  [96, 50, 91, 58, 83]
# 65  POINT (-74.07876 40.84232)   [40, 9, 51, 49, 48]
# 75  POINT (-74.27649 40.58957)  [97, 69, 92, 67, 15]
# 45  POINT (-73.89762 40.78156)   [62, 37, 44, 2, 56]
#
#                                         line_geometry
# 91  MULTILINESTRING ((-73.89955 40.58394, -73.8845...
# 29  MULTILINESTRING ((-74.0512 40.61603, -74.04581...
# 2   MULTILINESTRING ((-73.93834 40.79408, -73.9544...
# 50  MULTILINESTRING ((-73.95788 40.55978, -73.9480...
# 44  MULTILINESTRING ((-73.89994 40.82248, -73.9081...
# 78  MULTILINESTRING ((-74.12232 40.78177, -74.1107...
# 33  MULTILINESTRING ((-73.95894 40.61931, -73.9480...
# 65  MULTILINESTRING ((-74.07876 40.84232, -74.0843...
# 75  MULTILINESTRING ((-74.27649 40.58957, -74.2879...
# 45  MULTILINESTRING ((-73.89762 40.78156, -73.9062...

# %% [markdown]
# Let's plot the nearest neighbors and connecting edges for a single point. Below, we take a random point `s` and then highlight it in blue, and connect it to its five nearest neighbors in orange. Keep in mind that every time you rerun the following cell, a new sampled point will be chosen.

# %%
# plot the lines for a single point
s = gdf.sample()
ax = lines_gdf.plot(color="black", alpha=0.5, linewidth=0.2)
gdf.plot(ax=ax, color="red")

s.plot(ax=ax, color="blue")
gpd.GeoSeries(s.line_geometry).plot(ax=plt.gca(), color="orange")
# Out:
# <Axes: >

# %% [markdown]
# ## Apply to a real-world example

# %% [markdown]
# The toy problem above was a fine way to explore this concept, so now let's apply it to real-world networks. We will use an API endpoint hosted through [catalog.data.gov](https://catalog.data.gov/) to find MTA subway stations in NYC.
#
# There are a couple of things to keep in mind about the following API request. First is the request itself: we use the popular `requests` library to perform a `GET` request (there are many types of requests, read more [here](https://requests.readthedocs.io/en/latest/user/quickstart/#make-a-request)) on the API endpoint listed at the resource URL.
#
#
# We can see on the open data portal's website that the dataset has the option to download as JSON: :
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Get subway stations in NYC

# %% [markdown]
# If a query is successful, it will return a result that starts with `2**`, such as `200`. Error codes are reserved for `4**` and `5**`. We can make this most basic request first to confirm that our query is properly formatted:

# %%
requests.get("https://data.ny.gov/api/v3/views/39hk-dx4f/query.json?accessType=API")
# Out:
# <Response [200]>

# %% [markdown]
# What we really want, however, is the `json` associated with the response. We can create a new variable and set it to equal the response json payload:

# %%
subway_stations = requests.get(
    "https://data.ny.gov/api/v3/views/39hk-dx4f/query.json?accessType=API"
).json()

# %% [markdown]
# If we print the results, we see we have an array of objects (up to 2000) that represents the restaurants in `MN09`. If you scan through, you'll see attributes like street, building number, cuisine_description, and restaurant scores.

# %% [markdown]
# For these to be useful to us, let's cast the array as a geodataframe. Take a look at the resulting `subway_stations` JSON object to see how to translate the geometry into a geodataframe. Remember, we need to extract the lat and lon of the geometry JSON to pass to geopandas.

# %%
subway_stations[0]
# Out:
# {':id': 'row-3523-2f4j~u7nt',
#  ':version': 'rv-sw7x-24xf.jkj9',
#  ':created_at': '2026-07-24T04:15:49.117Z',
#  ':updated_at': '2026-07-24T04:15:53.449Z',
#  'gtfs_stop_id': 'R01',
#  'station_id': '1',
#  'complex_id': '1',
#  'division': 'BMT',
#  'line': 'Astoria',
#  'stop_name': 'Astoria-Ditmars Blvd',
#  'borough': 'Q',
#  'cbd': 'false',
#  'daytime_routes': 'N W',
#  'structure': 'Elevated',
#  'gtfs_latitude': '40.775036',
#  'gtfs_longitude': '-73.912034',
#  'north_direction_label': 'Last Stop',
#  'south_direction_label': 'Manhattan',
#  'ada': '0',
#  'ada_northbound': '0',
#  'ada_southbound': '0',
#  'georeference': {'type': 'Point', 'coordinates': [-73.912034, 40.775036]},
#  ':@computed_region_yamh_8v7k': '196',
#  ':@computed_region_wbg7_3whc': '877',
#  ':@computed_region_kjdx_g34t': '2137'}

# %%
subway_stations
# Out:
# [{':id': 'row-3523-2f4j~u7nt',
#   ':version': 'rv-sw7x-24xf.jkj9',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R01',
#   'station_id': '1',
#   'complex_id': '1',
#   'division': 'BMT',
#   'line': 'Astoria',
#   'stop_name': 'Astoria-Ditmars Blvd',
#   'borough': 'Q',
#   'cbd': 'false',
#   'daytime_routes': 'N W',
#   'structure': 'Elevated',
#   'gtfs_latitude': '40.775036',
#   'gtfs_longitude': '-73.912034',
#   'north_direction_label': 'Last Stop',
#   'south_direction_label': 'Manhattan',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.912034, 40.775036]},
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '877',
#   ':@computed_region_kjdx_g34t': '2137'},
#  {':id': 'row-8siw.4xgw.nvqe',
#   ':version': 'rv-8v4h.spb5-xbnx',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R03',
#   'station_id': '2',
#   'complex_id': '2',
#   'division': 'BMT',
#   'line': 'Astoria',
#   'stop_name': 'Astoria Blvd',
#   'borough': 'Q',
#   'cbd': 'false',
#   'daytime_routes': 'N W',
#   'structure': 'Elevated',
#   'gtfs_latitude': '40.770258',
#   'gtfs_longitude': '-73.917843',
#   'north_direction_label': 'Astoria',
#   'south_direction_label': 'Manhattan',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-73.917843, 40.770258]},
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '874',
#   ':@computed_region_kjdx_g34t': '2137'},
#  {':id': 'row-javd~wecq_zsff',
#   ':version': 'rv-hdit_cfci~5ax6',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R04',
#   'station_id': '3',
#   'complex_id': '3',
#   'division': 'BMT',
#   'line': 'Astoria',
#   'stop_name': '30 Av',
#   'borough': 'Q',
#   'cbd': 'false',
#   'daytime_routes': 'N W',
#   'structure': 'Elevated',
#   'gtfs_latitude': '40.766779',
#   'gtfs_longitude': '-73.921479',
#   'north_direction_label': 'Astoria',
#   'south_direction_label': 'Manhattan',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.921479, 40.766779]},
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '874',
#   ':@computed_region_kjdx_g34t': '2137'},
#  {':id': 'row-2e8r~ajpw~63ju',
#   ':version': 'rv-z7ah_qf9a-57cz',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R05',
#   'station_id': '4',
#   'complex_id': '4',
#   'division': 'BMT',
#   'line': 'Astoria',
#   'stop_name': 'Broadway',
#   'borough': 'Q',
#   'cbd': 'false',
#   'daytime_routes': 'N W',
#   'structure': 'Elevated',
#   'gtfs_latitude': '40.76182',
#   'gtfs_longitude': '-73.925508',
#   'north_direction_label': 'Astoria',
#   'south_direction_label': 'Manhattan',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.925508, 40.76182]},
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '878',
#   ':@computed_region_kjdx_g34t': '2137'},
#  {':id': 'row-ryyi.7fna_gkrz',
#   ':version': 'rv-t4wf_rwe3-pwsg',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R06',
#   'station_id': '5',
#   'complex_id': '5',
#   'division': 'BMT',
#   'line': 'Astoria',
#   'stop_name': '36 Av',
#   'borough': 'Q',
#   'cbd': 'false',
#   'daytime_routes': 'N W',
#   'structure': 'Elevated',
#   'gtfs_latitude': '40.756804',
#   'gtfs_longitude': '-73.929575',
#   'north_direction_label': 'Astoria',
#   'south_direction_label': 'Manhattan',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.929575, 40.756804]},
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '878',
#   ':@computed_region_kjdx_g34t': '2137'},
#  {':id': 'row-i8b7.r5ks~kb9j',
#   ':version': 'rv-sfbz-aj2p.b9gx',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R08',
#   'station_id': '6',
#   'complex_id': '6',
#   'division': 'BMT',
#   'line': 'Astoria',
#   'stop_name': '39 Av-Dutch Kills',
#   'borough': 'Q',
#   'cbd': 'false',
#   'daytime_routes': 'N W',
#   'structure': 'Elevated',
#   'gtfs_latitude': '40.752882',
#   'gtfs_longitude': '-73.932755',
#   'north_direction_label': 'Astoria',
#   'south_direction_label': 'Manhattan',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.932755, 40.752882]},
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '873',
#   ':@computed_region_kjdx_g34t': '2137'},
#  {':id': 'row-47km~erzx-qrx7',
#   ':version': 'rv-t7aw-2vmx~auka',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R11',
#   'station_id': '7',
#   'complex_id': '613',
#   'division': 'BMT',
#   'line': 'Astoria',
#   'stop_name': 'Lexington Av/59 St',
#   'borough': 'M',
#   'cbd': 'true',
#   'daytime_routes': 'N R W',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.76266',
#   'gtfs_longitude': '-73.967258',
#   'north_direction_label': 'Queens',
#   'south_direction_label': 'Downtown',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.967258, 40.76266]},
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '749',
#   ':@computed_region_kjdx_g34t': '2095'},
#  {':id': 'row-rn5v-zzbh~qdj4',
#   ':version': 'rv-m2at-wucb_hgnz',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R13',
#   'station_id': '8',
#   'complex_id': '8',
#   'division': 'BMT',
#   'line': 'Astoria',
#   'stop_name': '5 Av/59 St',
#   'borough': 'M',
#   'cbd': 'true',
#   'daytime_routes': 'N R W',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.764811',
#   'gtfs_longitude': '-73.973347',
#   'north_direction_label': 'Queens',
#   'south_direction_label': 'Downtown',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.973347, 40.764811]},
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_kjdx_g34t': '2095'},
#  {':id': 'row-ij4c~qe9v~5e7p',
#   ':version': 'rv-gmbh~h2p6.bynz',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R14',
#   'station_id': '9',
#   'complex_id': '9',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': '57 St-7 Av',
#   'borough': 'M',
#   'cbd': 'true',
#   'daytime_routes': 'N Q R W',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.764664',
#   'gtfs_longitude': '-73.980658',
#   'north_direction_label': 'Uptown',
#   'south_direction_label': 'Downtown',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-73.980658, 40.764664]},
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '742',
#   ':@computed_region_kjdx_g34t': '2095'},
#  {':id': 'row-pjnu_yki7.3yfg',
#   ':version': 'rv-nhxw_249y~hcti',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R15',
#   'station_id': '10',
#   'complex_id': '10',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': '49 St',
#   'borough': 'M',
#   'cbd': 'true',
#   'daytime_routes': 'N R W',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.759901',
#   'gtfs_longitude': '-73.984139',
#   'north_direction_label': 'Uptown',
#   'south_direction_label': 'Downtown',
#   'ada': '2',
#   'ada_northbound': '1',
#   'ada_southbound': '0',
#   'ada_notes': 'Uptown only',
#   'georeference': {'type': 'Point', 'coordinates': [-73.984139, 40.759901]},
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '742',
#   ':@computed_region_kjdx_g34t': '2095'},
#  {':id': 'row-9suu.u3ks.z7ax',
#   ':version': 'rv-ef3e_z3r8_mkk9',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R16',
#   'station_id': '11',
#   'complex_id': '611',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'Times Sq-42 St',
#   'borough': 'M',
#   'cbd': 'true',
#   'daytime_routes': 'N Q R W',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.754672',
#   'gtfs_longitude': '-73.986754',
#   'north_direction_label': 'Uptown',
#   'south_direction_label': 'Downtown',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-73.986754, 40.754672]},
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '741',
#   ':@computed_region_kjdx_g34t': '2095'},
#  {':id': 'row-p749_ji9q.vu6a',
#   ':version': 'rv-y4tp~cs5s.xywd',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R17',
#   'station_id': '12',
#   'complex_id': '607',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': '34 St-Herald Sq',
#   'borough': 'M',
#   'cbd': 'true',
#   'daytime_routes': 'N Q R W',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.749567',
#   'gtfs_longitude': '-73.98795',
#   'north_direction_label': 'Uptown',
#   'south_direction_label': 'Downtown',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-73.98795, 40.749567]},
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '717',
#   ':@computed_region_kjdx_g34t': '2095'},
#  {':id': 'row-bpbd-fvdb_sf4a',
#   ':version': 'rv-7jsv~9wzj_bjme',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R18',
#   'station_id': '13',
#   'complex_id': '13',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': '28 St',
#   'borough': 'M',
#   'cbd': 'true',
#   'daytime_routes': 'R W',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.745494',
#   'gtfs_longitude': '-73.988691',
#   'north_direction_label': 'Uptown',
#   'south_direction_label': 'Downtown',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.988691, 40.745494]},
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '717',
#   ':@computed_region_kjdx_g34t': '2095'},
#  {':id': 'row-kf5k~vtbu~px5r',
#   ':version': 'rv-a98e~ihc2~4rtn',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R19',
#   'station_id': '14',
#   'complex_id': '14',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': '23 St',
#   'borough': 'M',
#   'cbd': 'true',
#   'daytime_routes': 'R W',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.741303',
#   'gtfs_longitude': '-73.989344',
#   'north_direction_label': 'Uptown',
#   'south_direction_label': 'Downtown',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.989344, 40.741303]},
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '734',
#   ':@computed_region_kjdx_g34t': '2095'},
#  {':id': 'row-qgux_auma_4c2v',
#   ':version': 'rv-x3ry-h47y-jqgr',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R20',
#   'station_id': '15',
#   'complex_id': '602',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': '14 St-Union Sq',
#   'borough': 'M',
#   'cbd': 'true',
#   'daytime_routes': 'N Q R W',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.735736',
#   'gtfs_longitude': '-73.990568',
#   'north_direction_label': 'Uptown',
#   'south_direction_label': 'Downtown',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-73.990568, 40.735736]},
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '719',
#   ':@computed_region_kjdx_g34t': '2095'},
#  {':id': 'row-6zds_znpe-nycq',
#   ':version': 'rv-ziun~qreb-m2pt',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R21',
#   'station_id': '16',
#   'complex_id': '16',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': '8 St-NYU',
#   'borough': 'M',
#   'cbd': 'true',
#   'daytime_routes': 'R W',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.730328',
#   'gtfs_longitude': '-73.992629',
#   'north_direction_label': 'Uptown',
#   'south_direction_label': 'Downtown',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.992629, 40.730328]},
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '719',
#   ':@computed_region_kjdx_g34t': '2095'},
#  {':id': 'row-fjze_zjs9.v9iu',
#   ':version': 'rv-yunv~rhe2-h2f4',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R22',
#   'station_id': '17',
#   'complex_id': '17',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'Prince St',
#   'borough': 'M',
#   'cbd': 'true',
#   'daytime_routes': 'R W',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.724329',
#   'gtfs_longitude': '-73.997702',
#   'north_direction_label': 'Uptown',
#   'south_direction_label': 'Downtown',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.997702, 40.724329]},
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '736',
#   ':@computed_region_kjdx_g34t': '2095'},
#  {':id': 'row-t4e7.3wbv-3rep',
#   ':version': 'rv-4f9h_drmy.wwv6',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R23',
#   'station_id': '18',
#   'complex_id': '623',
#   'division': 'BMT',
#   'line': 'Broadway',
#   'stop_name': 'Canal St',
#   'borough': 'M',
#   'cbd': 'true',
#   'daytime_routes': 'R W',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.719527',
#   'gtfs_longitude': '-74.001775',
#   'north_direction_label': 'Uptown',
#   'south_direction_label': 'Downtown',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.001775, 40.719527]},
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '737',
#   ':@computed_region_kjdx_g34t': '2095'},
#  {':id': 'row-cpf6.zifb~2u8m',
#   ':version': 'rv-7mmq.r286.xv4b',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'Q01',
#   'station_id': '19',
#   'complex_id': '623',
#   'division': 'BMT',
#   'line': 'Manhattan Bridge',
#   'stop_name': 'Canal St',
#   'borough': 'M',
#   'cbd': 'true',
#   'daytime_routes': 'N Q',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.718383',
#   'gtfs_longitude': '-74.00046',
#   'north_direction_label': 'Uptown',
#   'south_direction_label': 'Downtown',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.00046, 40.718383]},
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '737',
#   ':@computed_region_kjdx_g34t': '2095'},
#  {':id': 'row-xxzc-vk6k_gz4k',
#   ':version': 'rv-5wii.vkb6_mi5i',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R24',
#   'station_id': '20',
#   'complex_id': '20',
#   'division': 'BMT',
#   'line': 'Broadway',
#   'stop_name': 'City Hall',
#   'borough': 'M',
#   'cbd': 'true',
#   'daytime_routes': 'R W',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.713282',
#   'gtfs_longitude': '-74.006978',
#   'north_direction_label': 'Uptown',
#   'south_direction_label': 'Downtown',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.006978, 40.713282]},
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '723',
#   ':@computed_region_kjdx_g34t': '2095'},
#  {':id': 'row-q7zg~tudw-u5p2',
#   ':version': 'rv-j7fr-qspj~km3z',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R25',
#   'station_id': '21',
#   'complex_id': '624',
#   'division': 'BMT',
#   'line': 'Broadway',
#   'stop_name': 'Cortlandt St',
#   'borough': 'M',
#   'cbd': 'true',
#   'daytime_routes': 'R W',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.710668',
#   'gtfs_longitude': '-74.011029',
#   'north_direction_label': 'Uptown',
#   'south_direction_label': 'Downtown',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-74.011029, 40.710668]},
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '723',
#   ':@computed_region_kjdx_g34t': '2095'},
#  {':id': 'row-sh3g~2n7g.h5g4',
#   ':version': 'rv-i5fw.rycc_6c4z',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R26',
#   'station_id': '22',
#   'complex_id': '22',
#   'division': 'BMT',
#   'line': 'Broadway',
#   'stop_name': 'Rector St',
#   'borough': 'M',
#   'cbd': 'true',
#   'daytime_routes': 'R W',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.70722',
#   'gtfs_longitude': '-74.013342',
#   'north_direction_label': 'Uptown',
#   'south_direction_label': 'Downtown',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.013342, 40.70722]},
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '722',
#   ':@computed_region_kjdx_g34t': '2095'},
#  {':id': 'row-4trh-tqy2~sy2h',
#   ':version': 'rv-tw8p_k2pt~m9vi',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R27',
#   'station_id': '23',
#   'complex_id': '635',
#   'division': 'BMT',
#   'line': 'Broadway',
#   'stop_name': 'Whitehall St-South Ferry',
#   'borough': 'M',
#   'cbd': 'true',
#   'daytime_routes': 'R W',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.703087',
#   'gtfs_longitude': '-74.012994',
#   'north_direction_label': 'Uptown',
#   'south_direction_label': 'Downtown',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.012994, 40.703087]},
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '720',
#   ':@computed_region_kjdx_g34t': '2095'},
#  {':id': 'row-qgpu_rbf3-6tap',
#   ':version': 'rv-q48g_vgny_di5v',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R28',
#   'station_id': '24',
#   'complex_id': '620',
#   'division': 'BMT',
#   'line': 'Broadway',
#   'stop_name': 'Court St',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'R',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.6941',
#   'gtfs_longitude': '-73.991777',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.991777, 40.6941]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '880',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-kp4h-pyu5_4m4n',
#   ':version': 'rv-hrsw-3h3j_pkah',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R29',
#   'station_id': '25',
#   'complex_id': '636',
#   'division': 'BMT',
#   'line': 'Broadway',
#   'stop_name': 'Jay St-MetroTech',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'R',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.69218',
#   'gtfs_longitude': '-73.985942',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-73.985942, 40.69218]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '880',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-knds-qy9f.rumd',
#   ':version': 'rv-cc6n_f2pc.iejd',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R30',
#   'station_id': '26',
#   'complex_id': '26',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'DeKalb Av',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'B Q R',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.690635',
#   'gtfs_longitude': '-73.981824',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-73.981824, 40.690635]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '880',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-8b3c~pw5s-9a7g',
#   ':version': 'rv-maxj-xya2-fvjc',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R31',
#   'station_id': '27',
#   'complex_id': '617',
#   'division': 'BMT',
#   'line': '4th Av',
#   'stop_name': 'Atlantic Av-Barclays Ctr',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'D N R',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.683666',
#   'gtfs_longitude': '-73.97881',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-73.97881, 40.683666]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '895',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-8gam_sumf.guxf',
#   ':version': 'rv-pvdp~pmja.byah',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R32',
#   'station_id': '28',
#   'complex_id': '28',
#   'division': 'BMT',
#   'line': '4th Av',
#   'stop_name': 'Union St',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'R',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.677316',
#   'gtfs_longitude': '-73.98311',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.98311, 40.677316]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '893',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-95yu~q99v.m78y',
#   ':version': 'rv-wv4x-ueeh~tpbt',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R33',
#   'station_id': '29',
#   'complex_id': '608',
#   'division': 'BMT',
#   'line': '4th Av',
#   'stop_name': '4 Av-9 St',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'R',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.670847',
#   'gtfs_longitude': '-73.988302',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.988302, 40.670847]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '893',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-2q24-dphb~3utz',
#   ':version': 'rv-e99c~fjpd_23mg',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R34',
#   'station_id': '30',
#   'complex_id': '30',
#   'division': 'BMT',
#   'line': '4th Av',
#   'stop_name': 'Prospect Av',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'R',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.665414',
#   'gtfs_longitude': '-73.992872',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.992872, 40.665414]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '893',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-c4vh-ex4v.adp7',
#   ':version': 'rv-n9p9_3xg2_xd84',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R35',
#   'station_id': '31',
#   'complex_id': '31',
#   'division': 'BMT',
#   'line': '4th Av',
#   'stop_name': '25 St',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'R',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.660397',
#   'gtfs_longitude': '-73.998091',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.998091, 40.660397]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '815',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-frc9.tnie.ns73',
#   ':version': 'rv-ae9f-7j46~3qm2',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R36',
#   'station_id': '32',
#   'complex_id': '32',
#   'division': 'BMT',
#   'line': '4th Av',
#   'stop_name': '36 St',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'D N R',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.655144',
#   'gtfs_longitude': '-74.003549',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.003549, 40.655144]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '815',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-gzzj~wsuu~ps2m',
#   ':version': 'rv-9bbk.mvye-ur3i',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R39',
#   'station_id': '33',
#   'complex_id': '33',
#   'division': 'BMT',
#   'line': '4th Av',
#   'stop_name': '45 St',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'R',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.648939',
#   'gtfs_longitude': '-74.010006',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.010006, 40.648939]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '899',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-46zh-mrbn-h3wk',
#   ':version': 'rv-f4hh~kfhv.cxip',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R40',
#   'station_id': '34',
#   'complex_id': '34',
#   'division': 'BMT',
#   'line': '4th Av',
#   'stop_name': '53 St',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'R',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.645069',
#   'gtfs_longitude': '-74.014034',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.014034, 40.645069]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '899',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-wujn~d6ig-2ttt',
#   ':version': 'rv-sh9r_jyef.xhwy',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R41',
#   'station_id': '35',
#   'complex_id': '35',
#   'division': 'BMT',
#   'line': '4th Av',
#   'stop_name': '59 St',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'N R',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.641362',
#   'gtfs_longitude': '-74.017881',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-74.017881, 40.641362]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '899',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-hq53~n36r~v4fq',
#   ':version': 'rv-6isf.u7ra~vek7',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R42',
#   'station_id': '36',
#   'complex_id': '36',
#   'division': 'BMT',
#   'line': '4th Av',
#   'stop_name': 'Bay Ridge Av',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'R',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.634967',
#   'gtfs_longitude': '-74.023377',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Bay Ridge',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.023377, 40.634967]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '899',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-f5pf-4nb6_ifpj',
#   ':version': 'rv-rpcy_5v6r_mxd7',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R43',
#   'station_id': '37',
#   'complex_id': '37',
#   'division': 'BMT',
#   'line': '4th Av',
#   'stop_name': '77 St',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'R',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.629742',
#   'gtfs_longitude': '-74.02551',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Bay Ridge',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.02551, 40.629742]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '887',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-atq9.vfsm.afaq',
#   ':version': 'rv-agdd-vkjy-vkp2',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R44',
#   'station_id': '38',
#   'complex_id': '38',
#   'division': 'BMT',
#   'line': '4th Av',
#   'stop_name': '86 St',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'R',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.622687',
#   'gtfs_longitude': '-74.028398',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Bay Ridge',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-74.028398, 40.622687]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '887',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-3nr4~ickv-xz9d',
#   ':version': 'rv-8ixj~tb7a.rrkj',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'R45',
#   'station_id': '39',
#   'complex_id': '39',
#   'division': 'BMT',
#   'line': '4th Av',
#   'stop_name': 'Bay Ridge-95 St',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'R',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.616622',
#   'gtfs_longitude': '-74.030876',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Last Stop',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-74.030876, 40.616622]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '887',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-37hw.jzrn~zhfp',
#   ':version': 'rv-iiuf_4tu7.a937',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D24',
#   'station_id': '40',
#   'complex_id': '617',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'Atlantic Av-Barclays Ctr',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'B Q',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.68446',
#   'gtfs_longitude': '-73.97689',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-73.97689, 40.68446]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '895',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-73fv.djew-86ew',
#   ':version': 'rv-yi2b-6khy.4bqg',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D25',
#   'station_id': '41',
#   'complex_id': '41',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': '7 Av',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'B Q',
#   'structure': 'Subway',
#   'gtfs_latitude': '40.67705',
#   'gtfs_longitude': '-73.972367',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.972367, 40.67705]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '895',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-7thm_9erh.nrpx',
#   ':version': 'rv-474b-4mdc.3jqg',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D26',
#   'station_id': '42',
#   'complex_id': '42',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'Prospect Park',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'B Q S',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.661614',
#   'gtfs_longitude': '-73.962246',
#   'north_direction_label': 'Northbound',
#   'south_direction_label': 'Southbound',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-73.962246, 40.661614]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '809',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-rmuc_w5h5.qf7m',
#   ':version': 'rv-esec_y6rj.zssg',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D27',
#   'station_id': '43',
#   'complex_id': '43',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'Parkside Av',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'Q',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.655292',
#   'gtfs_longitude': '-73.961495',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.961495, 40.655292]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '809',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-feab_7wq2_iatt',
#   ':version': 'rv-wr7n-tub7.w6bm',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D28',
#   'station_id': '44',
#   'complex_id': '44',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'Church Av',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'B Q',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.650527',
#   'gtfs_longitude': '-73.962982',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-73.962982, 40.650527]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '810',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-xqrf_hb9t.pnst',
#   ':version': 'rv-w882~ipkb~3ma5',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D29',
#   'station_id': '45',
#   'complex_id': '45',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'Beverley Rd',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'Q',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.644031',
#   'gtfs_longitude': '-73.964492',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.964492, 40.644031]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '810',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-4rnt.9qys_a5nr',
#   ':version': 'rv-mugg~hams~gybc',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D30',
#   'station_id': '46',
#   'complex_id': '46',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'Cortelyou Rd',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'Q',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.640927',
#   'gtfs_longitude': '-73.963891',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.963891, 40.640927]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '810',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-i46a-eq2b.ycp3',
#   ':version': 'rv-8ypj.g53s.jxca',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D31',
#   'station_id': '47',
#   'complex_id': '47',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'Newkirk Plaza',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'B Q',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.635082',
#   'gtfs_longitude': '-73.962793',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.962793, 40.635082]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '810',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-w662_mee6~8wk9',
#   ':version': 'rv-amzk_putt.ycrz',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D32',
#   'station_id': '48',
#   'complex_id': '48',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'Avenue H',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'Q',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.62927',
#   'gtfs_longitude': '-73.961639',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-73.961639, 40.62927]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '813',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-k36v-sxwh_wfar',
#   ':version': 'rv-tj68~xuqj.d46g',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D33',
#   'station_id': '49',
#   'complex_id': '49',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'Avenue J',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'Q',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.625039',
#   'gtfs_longitude': '-73.960803',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.960803, 40.625039]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '813',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-eqs7.ej4a-9bx8',
#   ':version': 'rv-sb4b.nb84.jv3k',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D34',
#   'station_id': '50',
#   'complex_id': '50',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'Avenue M',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'Q',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.617618',
#   'gtfs_longitude': '-73.959399',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.959399, 40.617618]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '813',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-2z3x~xmaa.un53',
#   ':version': 'rv-jnq4.yfui.fefy',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D35',
#   'station_id': '51',
#   'complex_id': '51',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'Kings Hwy',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'B Q',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.60867',
#   'gtfs_longitude': '-73.957734',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-73.957734, 40.60867]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '812',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-z3fs~zfn7.bsru',
#   ':version': 'rv-k96b-76en~v2jn',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D37',
#   'station_id': '52',
#   'complex_id': '52',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'Avenue U',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'Q',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.5993',
#   'gtfs_longitude': '-73.955929',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.955929, 40.5993]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '812',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-bsmm~xv3f_cs68',
#   ':version': 'rv-5zc8-udjy.2bh7',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D38',
#   'station_id': '53',
#   'complex_id': '53',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'Neck Rd',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'Q',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.595246',
#   'gtfs_longitude': '-73.955161',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.955161, 40.595246]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '812',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-dgfc-s2u2.e79r',
#   ':version': 'rv-7fks.frcp-ifz4',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D39',
#   'station_id': '54',
#   'complex_id': '54',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'Sheepshead Bay',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'B Q',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.586896',
#   'gtfs_longitude': '-73.954155',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-73.954155, 40.586896]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '818',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-b636.j2i4_gq5d',
#   ':version': 'rv-mahu.ynqs-8ehj',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D40',
#   'station_id': '55',
#   'complex_id': '55',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'Brighton Beach',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'B Q',
#   'structure': 'Elevated',
#   'gtfs_latitude': '40.577621',
#   'gtfs_longitude': '-73.961376',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.961376, 40.577621]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '818',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-su85.z3ty.j62n',
#   ':version': 'rv-8nab_8mj9_x3nx',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D41',
#   'station_id': '56',
#   'complex_id': '56',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'Ocean Pkwy',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'Q',
#   'structure': 'Elevated',
#   'gtfs_latitude': '40.576312',
#   'gtfs_longitude': '-73.968501',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Coney Island',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.968501, 40.576312]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '818',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-eqr4-g3qq~8ajx',
#   ':version': 'rv-jtgt.k9gq.qndy',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D42',
#   'station_id': '57',
#   'complex_id': '57',
#   'division': 'BMT',
#   'line': 'Broadway - Brighton',
#   'stop_name': 'W 8 St-NY Aquarium',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'F Q',
#   'structure': 'Elevated',
#   'gtfs_latitude': '40.576127',
#   'gtfs_longitude': '-73.975939',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Coney Island',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.975939, 40.576127]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '903',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-8si7-yjks~nf53',
#   ':version': 'rv-s3x2~u8fs.nq5e',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'D43',
#   'station_id': '58',
#   'complex_id': '58',
#   'division': 'BMT',
#   'line': 'Sea Beach / West End / Culver / Brighton',
#   'stop_name': 'Coney Island-Stillwell Av',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'D F N Q',
#   'structure': 'Viaduct',
#   'gtfs_latitude': '40.577422',
#   'gtfs_longitude': '-73.981233',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Last Stop',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-73.981233, 40.577422]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '903',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-npuc~33d2-h5bf',
#   ':version': 'rv-z6x3~awgm~s96p',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'B12',
#   'station_id': '59',
#   'complex_id': '59',
#   'division': 'BMT',
#   'line': 'West End',
#   'stop_name': '9 Av',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'D',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.646292',
#   'gtfs_longitude': '-73.994324',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.994324, 40.646292]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '897',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-8ajk.7x92~6te9',
#   ':version': 'rv-vtrv_bnbb-hfps',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'B13',
#   'station_id': '60',
#   'complex_id': '60',
#   'division': 'BMT',
#   'line': 'West End',
#   'stop_name': 'Fort Hamilton Pkwy',
#   'borough': 'Bk',
#   'cbd': 'false',
#   'daytime_routes': 'D',
#   'structure': 'Elevated',
#   'gtfs_latitude': '40.640914',
#   'gtfs_longitude': '-73.994304',
#   'north_direction_label': 'Manhattan',
#   'south_direction_label': 'Southbound',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-73.994304, 40.640914]},
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '897',
#   ':@computed_region_kjdx_g34t': '2090'},
#  {':id': 'row-qd5b.wqve-zvfv',
# ...
#  {':id': 'row-7dhx-ukbc-je4y',
#   ':version': 'rv-esns~ajsk-w7d8',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S30',
#   'station_id': '502',
#   'complex_id': '502',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'Tompkinsville',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'At Grade',
#   'gtfs_latitude': '40.636949',
#   'gtfs_longitude': '-74.074835',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'South Shore',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.074835, 40.636949]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '607'},
#  {':id': 'row-fy38-mjvf~i87x',
#   ':version': 'rv-s7ca_37g7~rmqa',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S29',
#   'station_id': '503',
#   'complex_id': '503',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'Stapleton',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'Elevated',
#   'gtfs_latitude': '40.627915',
#   'gtfs_longitude': '-74.075162',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'South Shore',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.075162, 40.627915]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '607',
#   ':@computed_region_kjdx_g34t': '2139'},
#  {':id': 'row-jb2d_u3b2-8w9k',
#   ':version': 'rv-huy7~2v6w-833v',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S28',
#   'station_id': '504',
#   'complex_id': '504',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'Clifton',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'Elevated',
#   'gtfs_latitude': '40.621319',
#   'gtfs_longitude': '-74.071402',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'South Shore',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.071402, 40.621319]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '607',
#   ':@computed_region_kjdx_g34t': '2139'},
#  {':id': 'row-stz6.3s6j-2dst',
#   ':version': 'rv-2pgc-mk75_wquu',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S27',
#   'station_id': '505',
#   'complex_id': '505',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'Grasmere',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.603117',
#   'gtfs_longitude': '-74.084087',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'South Shore',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.084087, 40.603117]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '607',
#   ':@computed_region_kjdx_g34t': '2139'},
#  {':id': 'row-hrjx.9se8_pq6q',
#   ':version': 'rv-pig9_pabp.237q',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S26',
#   'station_id': '506',
#   'complex_id': '506',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'Old Town',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'Embankment',
#   'gtfs_latitude': '40.596612',
#   'gtfs_longitude': '-74.087368',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'South Shore',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.087368, 40.596612]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '608',
#   ':@computed_region_kjdx_g34t': '2139'},
#  {':id': 'row-a8rn.stwa.f8k9',
#   ':version': 'rv-patd-vgby_t6xz',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S25',
#   'station_id': '507',
#   'complex_id': '507',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'Dongan Hills',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'Embankment',
#   'gtfs_latitude': '40.588849',
#   'gtfs_longitude': '-74.09609',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'South Shore',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-74.09609, 40.588849]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '608',
#   ':@computed_region_kjdx_g34t': '2139'},
#  {':id': 'row-q6sg.7332~k4f2',
#   ':version': 'rv-tne7_bbif-378f',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S24',
#   'station_id': '508',
#   'complex_id': '508',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'Jefferson Av',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'Embankment',
#   'gtfs_latitude': '40.583591',
#   'gtfs_longitude': '-74.103338',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'South Shore',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.103338, 40.583591]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '609',
#   ':@computed_region_kjdx_g34t': '2139'},
#  {':id': 'row-abmb-ifpk_jfky',
#   ':version': 'rv-2e5h.5w23~de2i',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S23',
#   'station_id': '509',
#   'complex_id': '509',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'Grant City',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.578965',
#   'gtfs_longitude': '-74.109704',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'South Shore',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.109704, 40.578965]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '609',
#   ':@computed_region_kjdx_g34t': '2139'},
#  {':id': 'row-qnh6_epq2.vsdr',
#   ':version': 'rv-6jdc~9c5c-bvhb',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S22',
#   'station_id': '510',
#   'complex_id': '510',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'New Dorp',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.57348',
#   'gtfs_longitude': '-74.11721',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'South Shore',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-74.11721, 40.57348]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '609',
#   ':@computed_region_kjdx_g34t': '2139'},
#  {':id': 'row-7e99_5x2h-wgue',
#   ':version': 'rv-cbc4-rbu3.7s9h',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S21',
#   'station_id': '511',
#   'complex_id': '511',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'Oakwood Heights',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.56511',
#   'gtfs_longitude': '-74.12632',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'South Shore',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.12632, 40.56511]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '609',
#   ':@computed_region_kjdx_g34t': '2139'},
#  {':id': 'row-zacn-khe4_78mw',
#   ':version': 'rv-2vah_4t9y.ea4e',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S20',
#   'station_id': '512',
#   'complex_id': '512',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'Bay Terrace',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'Embankment',
#   'gtfs_latitude': '40.5564',
#   'gtfs_longitude': '-74.136907',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'South Shore',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.136907, 40.5564]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '609',
#   ':@computed_region_kjdx_g34t': '2139'},
#  {':id': 'row-pemt.9dqy.fe7v',
#   ':version': 'rv-mwan-wtzd_p5m6',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S19',
#   'station_id': '513',
#   'complex_id': '513',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'Great Kills',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.551231',
#   'gtfs_longitude': '-74.151399',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'South Shore',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-74.151399, 40.551231]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '611',
#   ':@computed_region_kjdx_g34t': '2139'},
#  {':id': 'row-w89v-haxk-n87e',
#   ':version': 'rv-y3sw-ffe7~qbsm',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S18',
#   'station_id': '514',
#   'complex_id': '514',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'Eltingville',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'Embankment',
#   'gtfs_latitude': '40.544601',
#   'gtfs_longitude': '-74.16457',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'South Shore',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.16457, 40.544601]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '615',
#   ':@computed_region_kjdx_g34t': '2139'},
#  {':id': 'row-nvr4_m3m5~kvzr',
#   ':version': 'rv-nhxm-aksh~jq7y',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S17',
#   'station_id': '515',
#   'complex_id': '515',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'Annadale',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.54046',
#   'gtfs_longitude': '-74.178217',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'South Shore',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.178217, 40.54046]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '615',
#   ':@computed_region_kjdx_g34t': '2139'},
#  {':id': 'row-wbpm.eqem_pffa',
#   ':version': 'rv-xauv.6jb9~ivnx',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S16',
#   'station_id': '516',
#   'complex_id': '516',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'Huguenot',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.533674',
#   'gtfs_longitude': '-74.191794',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'South Shore',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.191794, 40.533674]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '615',
#   ':@computed_region_kjdx_g34t': '2139'},
#  {':id': 'row-h3sh~q368~ka2u',
#   ':version': 'rv-yqdw~fkiw_5tan',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S15',
#   'station_id': '517',
#   'complex_id': '517',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': "Prince's Bay",
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.525507',
#   'gtfs_longitude': '-74.200064',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'South Shore',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.200064, 40.525507]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '612',
#   ':@computed_region_kjdx_g34t': '2139'},
#  {':id': 'row-32hc-iewi-f2ek',
#   ':version': 'rv-np3s_geps_e4i3',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S14',
#   'station_id': '518',
#   'complex_id': '518',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'Pleasant Plains',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'Embankment',
#   'gtfs_latitude': '40.52241',
#   'gtfs_longitude': '-74.217847',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'South Shore',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.217847, 40.52241]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '612',
#   ':@computed_region_kjdx_g34t': '2139'},
#  {':id': 'row-gp6r-gwsn~hpj7',
#   ':version': 'rv-k536.6x6e~fxx5',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S13',
#   'station_id': '519',
#   'complex_id': '519',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'Richmond Valley',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'Open Cut',
#   'gtfs_latitude': '40.519631',
#   'gtfs_longitude': '-74.229141',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'Tottenville',
#   'ada': '0',
#   'ada_northbound': '0',
#   'ada_southbound': '0',
#   'georeference': {'type': 'Point', 'coordinates': [-74.229141, 40.519631]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '612',
#   ':@computed_region_kjdx_g34t': '2139'},
#  {':id': 'row-s585-gppp.cqqf',
#   ':version': 'rv-xs6u_ne9t.8mpv',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S09',
#   'station_id': '522',
#   'complex_id': '522',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'Tottenville',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'At Grade',
#   'gtfs_latitude': '40.512764',
#   'gtfs_longitude': '-74.251961',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'Last Stop',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-74.251961, 40.512764]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '610'},
#  {':id': 'row-3cih~5yyh~akab',
#   ':version': 'rv-6t5z~swwg.fy9b',
#   ':created_at': '2026-07-24T04:15:49.117Z',
#   ':updated_at': '2026-07-24T04:15:53.449Z',
#   'gtfs_stop_id': 'S11',
#   'station_id': '523',
#   'complex_id': '523',
#   'division': 'SIR',
#   'line': 'Staten Island',
#   'stop_name': 'Arthur Kill',
#   'borough': 'SI',
#   'cbd': 'false',
#   'daytime_routes': 'SIR',
#   'structure': 'At Grade',
#   'gtfs_latitude': '40.516578',
#   'gtfs_longitude': '-74.242096',
#   'north_direction_label': 'Ferry',
#   'south_direction_label': 'Tottenville',
#   'ada': '1',
#   'ada_northbound': '1',
#   'ada_southbound': '1',
#   'georeference': {'type': 'Point', 'coordinates': [-74.242096, 40.516578]},
#   ':@computed_region_yamh_8v7k': '585',
#   ':@computed_region_wbg7_3whc': '610',
#   ':@computed_region_kjdx_g34t': '2139'}]

# %%
subway_stations = gpd.GeoDataFrame(
    subway_stations,
    geometry=gpd.points_from_xy(
        [x["georeference"]["coordinates"][0] for x in subway_stations],
        [x["georeference"]["coordinates"][1] for x in subway_stations],
    ),
)

# %%
subway_stations.fillna("na", inplace=True)
# Out:
#                     :id           :version               :created_at  \
# 0    row-3523-2f4j~u7nt  rv-sw7x-24xf.jkj9  2026-07-24T04:15:49.117Z
# 1    row-8siw.4xgw.nvqe  rv-8v4h.spb5-xbnx  2026-07-24T04:15:49.117Z
# 2    row-javd~wecq_zsff  rv-hdit_cfci~5ax6  2026-07-24T04:15:49.117Z
# 3    row-2e8r~ajpw~63ju  rv-z7ah_qf9a-57cz  2026-07-24T04:15:49.117Z
# 4    row-ryyi.7fna_gkrz  rv-t4wf_rwe3-pwsg  2026-07-24T04:15:49.117Z
# ..                  ...                ...                       ...
# 491  row-h3sh~q368~ka2u  rv-yqdw~fkiw_5tan  2026-07-24T04:15:49.117Z
# 492  row-32hc-iewi-f2ek  rv-np3s_geps_e4i3  2026-07-24T04:15:49.117Z
# 493  row-gp6r-gwsn~hpj7  rv-k536.6x6e~fxx5  2026-07-24T04:15:49.117Z
# 494  row-s585-gppp.cqqf  rv-xs6u_ne9t.8mpv  2026-07-24T04:15:49.117Z
# 495  row-3cih~5yyh~akab  rv-6t5z~swwg.fy9b  2026-07-24T04:15:49.117Z
#
#                   :updated_at gtfs_stop_id station_id complex_id division  \
# 0    2026-07-24T04:15:53.449Z          R01          1          1      BMT
# 1    2026-07-24T04:15:53.449Z          R03          2          2      BMT
# 2    2026-07-24T04:15:53.449Z          R04          3          3      BMT
# 3    2026-07-24T04:15:53.449Z          R05          4          4      BMT
# 4    2026-07-24T04:15:53.449Z          R06          5          5      BMT
# ..                        ...          ...        ...        ...      ...
# 491  2026-07-24T04:15:53.449Z          S15        517        517      SIR
# 492  2026-07-24T04:15:53.449Z          S14        518        518      SIR
# 493  2026-07-24T04:15:53.449Z          S13        519        519      SIR
# 494  2026-07-24T04:15:53.449Z          S09        522        522      SIR
# 495  2026-07-24T04:15:53.449Z          S11        523        523      SIR
#
#               line             stop_name  ... south_direction_label ada  \
# 0          Astoria  Astoria-Ditmars Blvd  ...             Manhattan   0
# 1          Astoria          Astoria Blvd  ...             Manhattan   1
# 2          Astoria                 30 Av  ...             Manhattan   0
# 3          Astoria              Broadway  ...             Manhattan   0
# 4          Astoria                 36 Av  ...             Manhattan   0
# ..             ...                   ...  ...                   ...  ..
# 491  Staten Island          Prince's Bay  ...           South Shore   0
# 492  Staten Island       Pleasant Plains  ...           South Shore   0
# 493  Staten Island       Richmond Valley  ...           Tottenville   0
# 494  Staten Island           Tottenville  ...             Last Stop   1
# 495  Staten Island           Arthur Kill  ...           Tottenville   1
#
#     ada_northbound ada_southbound  \
# 0                0              0
# 1                1              1
# 2                0              0
# 3                0              0
# 4                0              0
# ..             ...            ...
# 491              0              0
# 492              0              0
# 493              0              0
# 494              1              1
# 495              1              1
#
#                                           georeference  \
# 0    {'type': 'Point', 'coordinates': [-73.912034, ...
# 1    {'type': 'Point', 'coordinates': [-73.917843, ...
# 2    {'type': 'Point', 'coordinates': [-73.921479, ...
# 3    {'type': 'Point', 'coordinates': [-73.925508, ...
# 4    {'type': 'Point', 'coordinates': [-73.929575, ...
# ..                                                 ...
# 491  {'type': 'Point', 'coordinates': [-74.200064, ...
# 492  {'type': 'Point', 'coordinates': [-74.217847, ...
# 493  {'type': 'Point', 'coordinates': [-74.229141, ...
# 494  {'type': 'Point', 'coordinates': [-74.251961, ...
# 495  {'type': 'Point', 'coordinates': [-74.242096, ...
#
#     :@computed_region_yamh_8v7k :@computed_region_wbg7_3whc  \
# 0                           196                         877
# 1                           196                         874
# 2                           196                         874
# 3                           196                         878
# 4                           196                         878
# ..                          ...                         ...
# 491                         585                         612
# 492                         585                         612
# 493                         585                         612
# 494                         585                         610
# 495                         585                         610
#
#     :@computed_region_kjdx_g34t ada_notes                    geometry
# 0                          2137        na  POINT (-73.91203 40.77504)
# 1                          2137        na  POINT (-73.91784 40.77026)
# 2                          2137        na  POINT (-73.92148 40.76678)
# 3                          2137        na  POINT (-73.92551 40.76182)
# 4                          2137        na   POINT (-73.92958 40.7568)
# ..                          ...       ...                         ...
# 491                        2139        na  POINT (-74.20006 40.52551)
# 492                        2139        na  POINT (-74.21785 40.52241)
# 493                        2139        na  POINT (-74.22914 40.51963)
# 494                          na        na  POINT (-74.25196 40.51276)
# 495                        2139        na   POINT (-74.2421 40.51658)
#
# [496 rows x 27 columns]

# %% [markdown]
# Now we can see that we have a dataframe with a number of columns, including a geometry column, that we can use to perform calculations on.

# %%
subway_stations.columns
# Out:
# Index([':id', ':version', ':created_at', ':updated_at', 'gtfs_stop_id',
#        'station_id', 'complex_id', 'division', 'line', 'stop_name', 'borough',
#        'cbd', 'daytime_routes', 'structure', 'gtfs_latitude', 'gtfs_longitude',
#        'north_direction_label', 'south_direction_label', 'ada',
#        'ada_northbound', 'ada_southbound', 'georeference',
#        ':@computed_region_yamh_8v7k', ':@computed_region_wbg7_3whc',
#        ':@computed_region_kjdx_g34t', 'ada_notes', 'geometry'],
#       dtype='str')

# %% [markdown]
# Let's inspect the number of stations by borough:

# %%
subway_stations.borough.value_counts()
# Out:
# borough
# Bk    169
# M     153
# Q      83
# Bx     70
# SI     21
# Name: count, dtype: int64

# %% [markdown]
# Additionally, let's check out the distribution of ADA accessibility in each borough (0=not accessible, 1=fully accessible, 2=partially accessible):

# %%
subway_stations.groupby("borough")["ada"].value_counts()
# Out:
# borough  ada
# Bk       0      124
#          1       43
#          2        2
# Bx       0       49
#          1       21
# M        0       83
#          1       64
#          2        6
# Q        0       54
#          1       28
#          2        1
# SI       0       15
#          1        6
# Name: count, dtype: int64

# %% [markdown]
# We can also see the distribution of stations in each borough based on their level of accessibility:

# %%
subway_stations.groupby("borough")["ada"].value_counts().div(
    subway_stations.groupby("borough")["ada"].count(), level="borough"
)  # expressed as proportions
# Out:
# borough  ada
# Bk       0      0.733728
#          1      0.254438
#          2      0.011834
# Bx       0      0.700000
#          1      0.300000
# M        0      0.542484
#          1      0.418301
#          2      0.039216
# Q        0      0.650602
#          1      0.337349
#          2      0.012048
# SI       0      0.714286
#          1      0.285714
# dtype: float64

# %% [markdown]
# ## Build a graph to allow us to search

# %% [markdown]
# Now that we have a geodataframe of subway stations, let's create a network based on the street grid of the neighborhood around a random station. To do so, we'll use the total geographic bounds of our restaurants dataframe to request a network from the `OSMnx` module. `OSMnx` is built on top of the `Networkx` library, and makes it easy for users to access information from `OpenStreetMap` for use in network analysis.

# %% [markdown]
# Like the name implies, we can build a network graph from the bbox above using the `graph_from_bbox()` function. We can specify that we are interested in a `walk` type network (i.e. pedestrian paths and sidewalks) using the `network_type` parameter (vs `driving` or `all` for example).
#
# Note too that the order of coordinates returned from the `total_bounds` property does not match the order that `OSMnx` expects it, so we have to reorder them via the `bbox` parameter.

# %%
home = (40.7998153, -73.9563997)

# %%
point_network = ox.graph_from_point(
    home,
    dist=1000,
    network_type="walk",
)

# %%
columbia = (40.80684196325087, -73.96114404069205)

# %%
home_node = ox.distance.nearest_nodes(point_network, X=home[1], Y=home[0])

# %%
columbia_node = ox.distance.nearest_nodes(point_network, X=columbia[1], Y=columbia[0])

# %%
route = ox.routing.shortest_path(
    point_network, home_node, columbia_node, weight="length"
)

# %%
fig, ax = ox.plot_graph_route(
    point_network,
    route,
    route_linewidth=4,
    node_size=0,
)

# %% [markdown]
# We can confirm that the result is a `networkx` multidirectional (`MultiDiGraph`) graph object:

# %%
point_network

# %% [markdown]
# ...and we can extract the nodes and edges of that network out as geodataframes:

# %%
net_nodes, net_edges = ox.graph_to_gdfs(point_network)

# %% [markdown]
# By inspecting the results, we can see that each row is a street network segment with a number of properties, all derived from OSM data.

# %%
net_edges.head()
# Out:
#                                osmid       highway lanes              name  \
# u        v           key
# 42427764 4347534774  0      46583189  unclassified     1  Grand Army Plaza
# 42427970 4378236618  0     420357623     secondary     4       York Avenue
# 42430358 3971196628  0    1211049194     secondary     4        6th Avenue
# 42430375 10173346243 0     569345537     secondary     4        6th Avenue
# 42430394 1283225261  0     576438593       service     1      Center Drive
#
#                           oneway reversed     length  \
# u        v           key
# 42427764 4347534774  0     False     True  12.317622
# 42427970 4378236618  0     False    False   9.841349
# 42430358 3971196628  0     False    False  23.771589
# 42430375 10173346243 0     False     True   8.303959
# 42430394 1283225261  0     False    False  15.477763
#
#                                                                    geometry  \
# u        v           key
# 42427764 4347534774  0    LINESTRING (-73.97411 40.76391, -73.97411 40.7...
# 42427970 4378236618  0    LINESTRING (-73.9579 40.76118, -73.95785 40.76...
# 42430358 3971196628  0    LINESTRING (-73.98042 40.75991, -73.98032 40.7...
# 42430375 10173346243 0    LINESTRING (-73.97814 40.76304, -73.97819 40.7...
# 42430394 1283225261  0    LINESTRING (-73.97624 40.76568, -73.9762 40.76...
#
#                          maxspeed access width bridge service tunnel junction
# u        v           key
# 42427764 4347534774  0        NaN    NaN   NaN    NaN     NaN    NaN      NaN
# 42427970 4378236618  0        NaN    NaN   NaN    NaN     NaN    NaN      NaN
# 42430358 3971196628  0        NaN    NaN   NaN    NaN     NaN    NaN      NaN
# 42430375 10173346243 0        NaN    NaN   NaN    NaN     NaN    NaN      NaN
# 42430394 1283225261  0     20 mph    NaN   NaN    NaN     NaN    NaN      NaN

# %% [markdown]
# We can take a look at the distribution of restaurants relative to our network by plotting both:

# %%
sample_station
# Out:
#                     :id           :version               :created_at  \
# 275  row-ud6m_efi9_rs6w  rv-rgc5.6tf9~j4p4  2026-07-24T04:15:49.117Z
#
#                   :updated_at gtfs_stop_id station_id complex_id division  \
# 275  2026-07-24T04:15:53.449Z          F11        275        612      IND
#
#             line           stop_name  ... ada_northbound ada_southbound  \
# 275  Queens Blvd  Lexington Av/53 St  ...              1              1
#
#                                           georeference  \
# 275  {'type': 'Point', 'coordinates': [-73.969055, ...
#
#     :@computed_region_yamh_8v7k :@computed_region_wbg7_3whc  \
# 275                         749                         749
#
#     :@computed_region_kjdx_g34t ada_notes                    geometry  \
# 275                        2095        na  POINT (-73.96906 40.75755)
#
#     distance                                         route_geom
# 275  0.64447  MULTILINESTRING ((-73.965844 40.7652673, -73.9...
#
# [1 rows x 29 columns]

# %%
ax = sample_station.plot()
net_edges.plot(ax=ax, color="black", linewidth=0.1)
# Out:
# <Axes: >

# %% [markdown]
# Let's take a look at the output- we can see a network of nodes and edges that represent the area around our sampled station. Note that unlike our toy example above, network edges here can have corners and curves and are not just individual line segments.

# %%
ax = net_edges.plot(color="black", linewidth=0.1, figsize=(10, 10))
net_nodes.plot(ax=ax, color="orange", markersize=1).set_axis_off()

# %% [markdown]
# Great - now that we have a network and locations to traverse, let's get a point to travel to/from.

# %% [markdown]
# ### Get directions to a random point

# %%
random_point = net_nodes.sample(1)

# %% [markdown]
# First we need to associate our starting point and target points to our networks. We begin by finding the nearest network nodes between an input coordinate and the network, for both our origin and a randomly selected restaurant.

# %%
orig = ox.distance.nearest_nodes(
    point_network, random_point.geometry.x, random_point.geometry.y
)[0]
dest = ox.distance.nearest_nodes(
    point_network, sample_station.iloc[0].geometry.x, sample_station.iloc[0].geometry.y
)

# %% [markdown]
# The above functions return the indices of the nearest network nodes:

# %%
orig, dest
# Out:
# (np.int64(10166171513), 10168635418)

# %% [markdown]
# Now that we have *network* positions, we can traverse the network to find the shortest path between each point. To do so, we'll use the `shortest_path()` function, and specify our `weight` as the `length` between start and end points. There are a number of options for weight, including the number of segments that need to be traversed, or a custom input you specify.
#
# OSMnx also has special helper functions to plot routes, which we'll use to plot the network and path between points.

# %%
# find the shortest path between nodes, minimizing travel distance, then plot it
route = ox.shortest_path(point_network, orig, dest, weight="length")
fig, ax = ox.plot_graph_route(point_network, route, node_size=10)

# %% [markdown]
# If we inspect the `route` on its own, we'll see an array of node ids that are ordered based on the shortest path that is generated.

# %%
route
# Out:
# [np.int64(10166171513),
#  11294619845,
#  11294619844,
#  10166860035,
#  10166860032,
#  10166860027,
#  10166509683,
#  10166509697,
#  10170751087,
#  10166509699,
#  13031153035,
#  13031153029,
#  13031070884,
#  13031070890,
#  13031070876,
#  13031070882,
#  10165922681,
#  10165922680,
#  10165922670,
#  10165922669,
#  10165922662,
#  10165922660,
#  12394019802,
#  12394016999,
#  12394019801,
#  10168547816,
#  10168635417,
#  10168635418]

# %% [markdown]
# That's not super useful to us- thankfully OSMnx makes it easy to convert the route to a geodataframe for use elsewhere. We can also use some basic math to convert the path from meters to miles to put things in perspective.

# %%
edge_lengths = ox.routing.route_to_gdf(point_network, route)["length"]

# convert meters to miles
sum(edge_lengths) / 1609.34
# Out:
# 0.6444700051509803

# %%
def distance_from_point(row, origin):
    """
    Returns the distance in miles and the geometry of the shortest path between a point and a destination.

    Parameters:
    row (pd.Series): A row from a pandas DataFrame.
    origin (int): The origin node in the network.
    """

    dest = ox.distance.nearest_nodes(point_network, row.geometry.x, row.geometry.y)
    route = ox.shortest_path(point_network, origin, dest, weight="length")
    edge_lengths = ox.routing.route_to_gdf(point_network, route)["length"]

    route_geom = ox.routing.route_to_gdf(point_network, route)
    route_geom = route_geom.geometry.union_all()

    return {"distance": sum(edge_lengths) / 1609.34, "route_geom": route_geom}

# %%
sample_station.loc[:, "distance_to_point"] = sample_station.apply(
    distance_from_point, origin=orig, axis=1
)

# %% [markdown]
# If we observe our results, we can see that each row (e.g. each pizza restaurant) has a dictionary of distance in miles and the shortest path. Pretty neat, but not super ergonomic in its current form.

# %%
sample_station["distance_to_point"]
# Out:
# 275    {'distance': 0.6444700051509803, 'route_geom':...
# Name: distance_to_point, dtype: object

# %% [markdown]
# We can explode each dictionary key:value pair into a separate column using the below operation. We are combining three different steps in the below cell to achieve this:
# - converting the entries in the `distance_from_class` attribute into a `pd.Series`- this is what does the separating into separate columns
# - `drop`ping the `distance_from_class` field, as we no longer need it
# - using the `concat(...)` function to concatenate the results of the other two operations; this allows us to combine things back together into our one dataframe

# %%
# explode the dictionary into separate columns
sample_station = pd.concat(
    [
        sample_station.drop(["distance_to_point"], axis=1),
        sample_station["distance_to_point"].apply(pd.Series),
    ],
    axis=1,
)

# %% [markdown]
# Now we can see we have each of the dictionary entries as new columns, and now we can operate over both in our dataframe.

# %%
sample_station.head()
# Out:
#                     :id           :version               :created_at  \
# 275  row-ud6m_efi9_rs6w  rv-rgc5.6tf9~j4p4  2026-07-24T04:15:49.117Z
#
#                   :updated_at gtfs_stop_id station_id complex_id division  \
# 275  2026-07-24T04:15:53.449Z          F11        275        612      IND
#
#             line           stop_name  ... ada_northbound ada_southbound  \
# 275  Queens Blvd  Lexington Av/53 St  ...              1              1
#
#                                           georeference  \
# 275  {'type': 'Point', 'coordinates': [-73.969055, ...
#
#     :@computed_region_yamh_8v7k :@computed_region_wbg7_3whc  \
# 275                         749                         749
#
#     :@computed_region_kjdx_g34t ada_notes                    geometry  \
# 275                        2095        na  POINT (-73.96906 40.75755)
#
#     distance                                         route_geom
# 275  0.64447  MULTILINESTRING ((-73.965844 40.7652673, -73.9...
#
# [1 rows x 29 columns]

# %% [markdown]
# Now let's cast our results to a new geodataframe with the `geometry` set as the routes calculated above.

# %%
sample_station_routes = gpd.GeoDataFrame(
    sample_station, geometry="route_geom", crs="EPSG:4326"
)

# %% [markdown]
# Now we can plot each pizza restaurant, the shortest path between here and there, and can symbolize based on the distance in miles:

# %%
import contextily as cx

# %%
ax = sample_station.plot(color="black", figsize=(10, 10))
sample_station_routes.plot(column="distance", cmap="magma", ax=ax, linewidth=3)
sample_station.plot(column="distance", cmap="magma", legend=True, ax=ax)
cx.add_basemap(ax, crs="EPSG:4326", source=cx.providers.CartoDB.Voyager)


# title
plt.title(
    f"Distance from point to subway station: {round(sample_station['distance'].min(), 2)} mi"
)
# Out:
# Text(0.5, 1.0, 'Distance from point to subway station: 0.64 mi')

# %% [markdown]
# Great- we can now visualize and intuit the closest pizza places. If we want to look at the actual numbers, we can sort by distance and observe. Note that the top two entries are tied, which suggest that both were snapped to the same network node (which is a consideration to keep in mind when we rely on third-party datasets like OSM)

# %% [markdown]
# ## Calculating walksheds

# %%
network_type = "walk"
trip_times = [5, 10, 15, 20, 25]  # in minutes
travel_speed = 4.5  # walking speed in km/hour

# %%
iso_colors = ox.plot.get_colors(n=len(trip_times), cmap="plasma", start=0)

# %%
# color the nodes according to isochrone then plot the street network

nodes_outside = []
node_colors = {}

for trip_time, color in zip(sorted(trip_times, reverse=True), iso_colors, strict=False):
    subgraph = nx.ego_graph(point_network, home_node, radius=trip_time, distance="time")

    for node in subgraph.nodes():
        node_colors[node] = color

nc = [node_colors.get(node, "none") for node in point_network.nodes()]

ns = [15 if node in node_colors else 0 for node in point_network.nodes()]

nodes_outside.extend(
    [node for node in point_network.nodes() if node not in node_colors]
)

nodes_outside = list(set(nodes_outside))

fig, ax = ox.plot.plot_graph(
    point_network,
    node_color=nc,
    node_size=ns,
    node_alpha=0.8,
    edge_linewidth=0.2,
    edge_color="#999999",
)

# %%
# plot nodes outside walkzone
nodes_outside_graph = point_network.subgraph(nodes_outside)
fig, ax = ox.plot.plot_graph(
    nodes_outside_graph,
    node_color="red",
    node_size=15,
    node_alpha=0.8,
    edge_linewidth=0.2,
    edge_color="#999999",
)

# %% [markdown]
# # Use grid cells to build and traverse a network

# %% [markdown]
# So far, we've been able to create networks from a random distribution of points, as well as from the street network of a real-world location. For our final example, let's explore how we can use a grid of cells to create a network and traverse it. More specifically, we'll create a grid of hexagons, and then connect each hexagon to its nearest neighbors using the [h3 library](https://uber.github.io/h3-py/intro.html). H3 was developed by Uber and represents a hierarchical spatial index that uses hexagonal grid cells to partition space. Hexagons are useful for this purpose because they have a number of desirable properties, including uniform adjacency (each hexagon has six neighbors), reduced distortion compared to square grids, and efficient coverage of large areas.

# %%
# use H3 grid to create a hexagon around the restaurants
# count the number of restaurants in each hexagon
# use pysal to get adjacency between hexagons
# build new network with hexagons as nodes and their adjacency as edges
# use networkx to find the shortest path between hexagons

# get the H3 hexagons

# %%
net_nodes
# Out:
#                      y          x          highway  street_count railway  \
# osmid
# 42427764     40.763914 -73.974107  traffic_signals             1     NaN
# 42427970     40.761182 -73.957902  traffic_signals             1     NaN
# 42430358     40.759911 -73.980418  traffic_signals             1     NaN
# 42430375     40.763042 -73.978141  traffic_signals             1     NaN
# 42430394     40.765680 -73.976244  traffic_signals             1     NaN
# ...                ...        ...              ...           ...     ...
# 13958194444  40.752381 -73.970170              NaN             4     NaN
# 13958194449  40.752882 -73.969801              NaN             4     NaN
# 13958194452  40.752999 -73.969714              NaN             4     NaN
# 13958194455  40.753008 -73.970069              NaN             4     NaN
# 13958194456  40.753120 -73.969987              NaN             4     NaN
#
#                                geometry
# osmid
# 42427764     POINT (-73.97411 40.76391)
# 42427970      POINT (-73.9579 40.76118)
# 42430358     POINT (-73.98042 40.75991)
# 42430375     POINT (-73.97814 40.76304)
# 42430394     POINT (-73.97624 40.76568)
# ...                                 ...
# 13958194444  POINT (-73.97017 40.75238)
# 13958194449   POINT (-73.9698 40.75288)
# 13958194452    POINT (-73.96971 40.753)
# 13958194455  POINT (-73.97007 40.75301)
# 13958194456  POINT (-73.96999 40.75312)
#
# [1886 rows x 6 columns]

# %% [markdown]
# Here we are querying the H3 dataset at resolution 9 for each node in our network. You can read more about H3 resolutions [here](https://h3geo.org/docs/core-library/restable/). This will return a unique hexagon id for each point in our network. We will deduplicate these momentarily and create a new dataframe of hexagons.

# %%
net_nodes["h3"] = net_nodes.apply(
    lambda x: h3.latlng_to_cell(x.geometry.centroid.y, x.geometry.centroid.x, 9), axis=1
)

# %%
net_nodes["h3"]
# Out:
# osmid
# 42427764       892a100d61bffff
# 42427970       892a100d44fffff
# 42430358       892a100d647ffff
# 42430375       892a100d657ffff
# 42430394       892a100d6cfffff
#                     ...
# 13958194444    892a100d623ffff
# 13958194449    892a100d623ffff
# 13958194452    892a100d623ffff
# 13958194455    892a100d623ffff
# 13958194456    892a100d623ffff
# Name: h3, Length: 1886, dtype: str

# %% [markdown]
# We can use the `h3_to_geo_boundary()` function to get the polygon geometry of each hexagon, and then populate a new field based on that geometry.

# %%
# create hexagons for AOI
net_nodes["geometry"] = net_nodes["h3"].apply(lambda x: (h3.cell_to_boundary(x)))
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_36368\494313494.py:2: UserWarning: Geometry column does not contain geometry.
#   net_nodes["geometry"] = net_nodes["h3"].apply(lambda x: (h3.cell_to_boundary(x)))

# %%
net_nodes["geometry"]
# Out:
# osmid
# 42427764       ((40.765179682522856, -73.97562131741019), (40...
# 42427970       ((40.76305501339731, -73.95627150348521), (40....
# 42430358       ((40.76236519526145, -73.98193393860953), (40....
# 42430375       ((40.76506439339491, -73.979898617382), (40.76...
# 42430394       ((40.7677636425751, -73.97786306535866), (40.7...
#                                      ...
# 13958194444    ((40.754729328676994, -73.9709331823963), (40....
# 13958194449    ((40.754729328676994, -73.9709331823963), (40....
# 13958194452    ((40.754729328676994, -73.9709331823963), (40....
# 13958194455    ((40.754729328676994, -73.9709331823963), (40....
# 13958194456    ((40.754729328676994, -73.9709331823963), (40....
# Name: geometry, Length: 1886, dtype: object

# %% [markdown]
# Unfortunately H3 returns the polygon vertices in the opposite order that `shapely` expects them, so we have to reverse the order of the coordinates. We can do so using a list comprehension. While we're at it, we can also cast the coordinates as a `Polygon` geometry.

# %%
# flip order of coordinates for each tuple
net_nodes["geometry"] = net_nodes["geometry"].apply(
    lambda x: Polygon([(y, x) for x, y in x])
)

# %% [markdown]
# We can assign the geometry a crs now that we know it is in lat/lon

# %%
net_nodes.crs = "EPSG:4326"

# %%
net_nodes.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# Finally, we'll create a new, deduplicated dataframe of hexagons.

# %%
h3_lvl_9_cells = net_nodes.dissolve(by="h3").copy().reset_index()

# %%
h3_lvl_9_cells.boundary.plot()
# Out:
# <Axes: >

# %% [markdown]
# Great, now let's overlay the hex grid on top of our road network to get a sense of scale and how this new network compares.

# %%
ax = h3_lvl_9_cells.boundary.plot(color="black", figsize=(10, 10))
net_edges.plot(
    ax=ax,
    color="black",
    linewidth=0.1,
)
# Out:
# <Axes: >

# %% [markdown]
# As we can see, the hexagons are fairly small, reasonably appropriate for the scale of our analysis (i.e. traversing city blocks). Next, we will create a network by connecting each hexagon to its six nearest neighbors. While `h3` has some native functions to calculate grid adjacency, we will use the more general purpose library `libpysal` to do so. `libpysal` is a spatial analysis library that has a number of useful functions, including the ability to calculate spatial weights and relationships between geometries.
#
# We will caalculate a spatial weights matrix using the `Queen` contiguity method, which considers two polygons to be neighbors if they share a common edge or vertex. This is appropriate for our hexagonal grid, as each hexagon has six neighbors that share edges.

# %%
# create an adjacency matrix for the hexagons
w = lps.weights.Queen.from_dataframe(h3_lvl_9_cells)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_36368\471419787.py:2: FutureWarning: `use_index` defaults to False but will default to True in future. Set True/False directly to control this behavior and silence this warning
#   w = lps.weights.Queen.from_dataframe(h3_lvl_9_cells)

# %%
w.neighbors.items()
# Out:
# dict_items([(0, [18, 20, 5]), (1, [2, 18, 22]), (2, [1, 37, 22, 39]), (3, [4, 5, 6]), (4, [3, 19, 5, 6, 20, 28]), (5, [0, 3, 20, 4]), (6, [3, 4, 28]), (7, [32, 35, 8, 9, 40]), (8, [40, 41, 7]), (9, [35, 7]), (10, [16, 11, 12, 13, 14, 15]), (11, [21, 38, 23, 10, 13, 15]), (12, [16, 29, 26, 24, 10, 13]), (13, [23, 10, 11, 12, 29, 30]), (14, [16, 33, 34, 10, 43, 15]), (15, [34, 42, 38, 10, 11, 14]), (16, [26, 10, 43, 44, 12, 14]), (17, [18, 19, 20, 21, 22, 23]), (18, [0, 1, 17, 20, 22]), (19, [17, 4, 20, 23, 28, 30]), (20, [0, 17, 18, 19, 4, 5]), (21, [17, 23, 38, 39, 22, 11]), (22, [1, 2, 17, 18, 21, 39]), (23, [17, 19, 21, 11, 13, 30]), (24, [26, 12, 29]), (25, [26, 44]), (26, [16, 24, 25, 12, 44]), (27, [28, 29, 30]), (28, [19, 4, 6, 27, 30]), (29, [24, 27, 12, 13, 30]), (30, [29, 19, 23, 27, 28, 13]), (31, [32, 33, 34, 35]), (32, [34, 35, 7, 40, 42, 31]), (33, [34, 43, 14, 31]), (34, [32, 33, 42, 31, 14, 15]), (35, [32, 9, 31, 7]), (36, [37, 38, 39, 40, 41, 42]), (37, [41, 2, 36, 39]), (38, [36, 21, 39, 42, 11, 15]), (39, [2, 36, 37, 38, 21, 22]), (40, [32, 36, 7, 8, 41, 42]), (41, [8, 40, 36, 37]), (42, [32, 34, 36, 38, 40, 15]), (43, [16, 33, 44, 14]), (44, [16, 25, 26, 43])])

# %% [markdown]
# Just like with the *n*-nearest neighbors example above, we can use the spatial weights matrix to create a list of neighboring hexagons for each row in our dataframe. We can use dictionary comprehension to create a mapping of each hexagon's index to its list of neighbors, and then create a graph network from that mapping using `networkx`.

# %%
# get neighbors for each hexagon
neighbors = {k: v for k, v in w.neighbors.items()}

# %%
neighbors
# Out:
# {0: [18, 20, 5],
#  1: [2, 18, 22],
#  2: [1, 37, 22, 39],
#  3: [4, 5, 6],
#  4: [3, 19, 5, 6, 20, 28],
#  5: [0, 3, 20, 4],
#  6: [3, 4, 28],
#  7: [32, 35, 8, 9, 40],
#  8: [40, 41, 7],
#  9: [35, 7],
#  10: [16, 11, 12, 13, 14, 15],
#  11: [21, 38, 23, 10, 13, 15],
#  12: [16, 29, 26, 24, 10, 13],
#  13: [23, 10, 11, 12, 29, 30],
#  14: [16, 33, 34, 10, 43, 15],
#  15: [34, 42, 38, 10, 11, 14],
#  16: [26, 10, 43, 44, 12, 14],
#  17: [18, 19, 20, 21, 22, 23],
#  18: [0, 1, 17, 20, 22],
#  19: [17, 4, 20, 23, 28, 30],
#  20: [0, 17, 18, 19, 4, 5],
#  21: [17, 23, 38, 39, 22, 11],
#  22: [1, 2, 17, 18, 21, 39],
#  23: [17, 19, 21, 11, 13, 30],
#  24: [26, 12, 29],
#  25: [26, 44],
#  26: [16, 24, 25, 12, 44],
#  27: [28, 29, 30],
#  28: [19, 4, 6, 27, 30],
#  29: [24, 27, 12, 13, 30],
#  30: [29, 19, 23, 27, 28, 13],
#  31: [32, 33, 34, 35],
#  32: [34, 35, 7, 40, 42, 31],
#  33: [34, 43, 14, 31],
#  34: [32, 33, 42, 31, 14, 15],
#  35: [32, 9, 31, 7],
#  36: [37, 38, 39, 40, 41, 42],
#  37: [41, 2, 36, 39],
#  38: [36, 21, 39, 42, 11, 15],
#  39: [2, 36, 37, 38, 21, 22],
#  40: [32, 36, 7, 8, 41, 42],
#  41: [8, 40, 36, 37],
#  42: [32, 34, 36, 38, 40, 15],
#  43: [16, 33, 44, 14],
#  44: [16, 25, 26, 43]}

# %% [markdown]
# Here we create a new graph `G` based on this adjacency matrix.

# %%
G = nx.Graph(neighbors)

# %% [markdown]
# Let's take a look at the graph- each node ID is plotted on the centroid of each hexagon, and the edges represent the connections between each hexagon and its six neighbors. As before, we can ignore the geographic CRS warning for this example.

# %%
# plot the path
ax = h3_lvl_9_cells.plot()
h3_lvl_9_cells.boundary.plot(ax=ax, color="black")

# label cells with their index
for x, y, label in zip(
    h3_lvl_9_cells.geometry.centroid.x,
    h3_lvl_9_cells.geometry.centroid.y,
    neighbors.keys(),
):
    ax.text(x, y, label, fontsize=6)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_36368\2249710294.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   h3_lvl_9_cells.geometry.centroid.x,
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_36368\2249710294.py:8: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   h3_lvl_9_cells.geometry.centroid.y,

# %% [markdown]
# Now we can inspect the adjacency dictionary above and understand how the adjacency is structured. Each key is a hexagon index, and the value is a list of adjacent hexagon indices.
#
# With this in mind, we can use `networkx` and the `shortest_path()` function to find the shortest path between two hexagons by passing the graph `G` and two hexagon indices. Here we are finding the shortest path between hexagon `8` and hexagon `29`.

# %%
# get the path between two nodes
path = nx.shortest_path(G, 15, 22)

# %% [markdown]
# The path is returned as a list of hexagon indices that represent the shortest path between the two input hexagons.

# %%
path
# Out:
# [15, 11, 21, 22]

# %% [markdown]
# Finally, let's visualize the path on top of the hexagon grid. We can use the `iloc[...]` function to look up the hexagons in `path` by their indices, and then plot the resulting geometries.

# %%
# plot the path
ax = h3_lvl_9_cells.plot()
h3_lvl_9_cells.boundary.plot(ax=ax, color="black")
h3_lvl_9_cells.iloc[path].plot(ax=ax, color="red")

# label cells with their index
for x, y, label in zip(
    h3_lvl_9_cells.geometry.centroid.x,
    h3_lvl_9_cells.geometry.centroid.y,
    neighbors.keys(),
):
    ax.text(x, y, label, fontsize=6)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_36368\2962518818.py:8: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   h3_lvl_9_cells.geometry.centroid.x,
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_36368\2962518818.py:9: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   h3_lvl_9_cells.geometry.centroid.y,

# %% [markdown]
# As we can see, the shortest path between the first and second hexagon passes through a number of intermediate hexagons, following the edges of the hexagonal grid. We can imagine cases where this type of grid-based network analysis could be useful.
#
# One thing we didn't explore as much here is the idea of *cost* or *weight* associated with traversing between nodes. In our street network example above, we used the `length` of each street segment as the weight for calculating the shortest path. We could just as easily assign other weights, such as travel time, elevation change, degree of sun exposure, etc. Think about the possibilities!
