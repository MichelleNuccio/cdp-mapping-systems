# %% [markdown]
# # Assignment 03 — Networks
#
# ## Euclidean vs network distance in my affective Milan
#
# This notebook follows the course tutorial [`04_networks.ipynb`](../../Tutorials/04_networks.ipynb) (`osmnx`, `networkx`) and applies it to the personal Milan geography from Assignment 02.
#
# ### Research statement
#
# I move through Milan mainly by bicycle. The places that matter to me — home, friends' homes, parks, bars, study and work sites — form a personal geography of the city. Official maps and straight-line (Euclidean) distance suggest that some destinations are "close." Everyday cycling, however, follows the street network: one-way systems, bridges, parks that block through-routes, and missing cycle links stretch or shorten lived distance.
#
# **Research question:** for the places that make up my affective Milan, how does *network* (bicycle) distance from home differ from *Euclidean* distance, and what does that gap say about the experiential geography of moving by bike?
#
# ### What this notebook does
#
# 1. Rebuilds the tutorial's **abstract network** (k-nearest neighbors) to fix concepts of nodes and edges.
# 2. Loads my **personal places** GeoJSON.
# 3. Downloads a **bicycle street network** from OpenStreetMap with OSMnx.
# 4. Measures **Euclidean** and **network** distance from home to every destination.
# 5. Produces **maps and charts**, then a short **reflection**.

# %% [markdown]
# ## 0. Import libraries

# %%
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import LineString, MultiLineString
import pandas as pd
import networkx as nx
import osmnx as ox
from pathlib import Path

from cdptools import utils

utils.set_axis_off()
ox.settings.use_cache = True
ox.settings.log_console = False

DATA_DIR = Path(".").resolve()
PLACES_PATH = DATA_DIR / "02-Psychogeograpy-MyMilan.geojson"

# %% [markdown]
# ## 1. Abstract network (tutorial warm-up)
#
# As in the tutorial, we start with a toy graph: random points connected to their *k* nearest neighbors by Euclidean distance. This makes the vocabulary of **nodes** and **edges** concrete before we move to a real street network.

# %%
from matplotlib import font_manager
from pathlib import Path

# Cascadia Code font (course assets)
FONT_PATH = (
    Path("..") / "assets" / "fonts" / "CascadiaCode" / "CascadiaCode.ttf"
).resolve()
font_manager.fontManager.addfont(str(FONT_PATH))
cascadia = font_manager.FontProperties(fname=str(FONT_PATH))
plt.rcParams["font.family"] = cascadia.get_name()

ELECTRIC_BLUE = "#2600FF"

# Bounding box roughly covering my personal places in Milan
bbox_milan = (9.17, 45.44, 9.29, 45.52)  # west, south, east, north

np.random.seed(0)
n = 40
toy = gpd.GeoDataFrame(
    {
        "geometry": gpd.points_from_xy(
            np.random.uniform(bbox_milan[0], bbox_milan[2], n),
            np.random.uniform(bbox_milan[1], bbox_milan[3], n),
        )
    },
    crs="EPSG:4326",
)
toy["label"] = [f"Point #{i:02d}" for i in range(1, len(toy) + 1)]

# Project to meters for meaningful neighbor distances
toy_m = toy.to_crs(32632)
toy_m["label"] = toy["label"].values

k = 4
neighbors = toy_m.geometry.apply(lambda x: toy_m.geometry.distance(x)).values.argsort(
    axis=1
)[:, 1 : k + 1]
toy_m["neighbors"] = neighbors.tolist()


def create_lines(row, nodes):
    lines = [LineString([row.geometry, nodes.loc[j].geometry]) for j in row.neighbors]
    return MultiLineString(lines)


toy_m["line_geometry"] = toy_m.apply(create_lines, nodes=toy_m, axis=1)
toy_edges = gpd.GeoDataFrame(
    toy_m[["line_geometry"]], geometry="line_geometry", crs=toy_m.crs
)

fig, ax = plt.subplots(figsize=(8, 8))

# Dotted electric-blue edges (draw explicitly so linestyle is respected)
for geom in toy_edges.geometry:
    lines = geom.geoms if geom.geom_type == "MultiLineString" else [geom]
    for line in lines:
        xs, ys = line.xy
        ax.plot(
            xs,
            ys,
            color=ELECTRIC_BLUE,
            linestyle=":",
            linewidth=0.5,
            solid_capstyle="round",
            zorder=1,
        )

toy_m.plot(
    ax=ax,
    color=ELECTRIC_BLUE,
    markersize=90,
    marker="+",
    linewidth=1,
    zorder=3,
)

# Point labels next to each node
for _idx, row in toy_m.iterrows():
    ax.annotate(
        row["label"],
        xy=(row.geometry.x, row.geometry.y),
        xytext=(4, 4),
        textcoords="offset points",
        fontsize=7,
        fontproperties=cascadia,
        color="#222222",
    )

ax.set_title(
    "Toy network: each node linked to 4 Euclidean nearest neighbors",
    fontproperties=cascadia,
    fontsize=9,
)
plt.show()

# %% [markdown]
# ## 2. Load personal places (nodes of interest)
#
# These are the **nodes for which we measure distance**: home as origin; friends' homes and favorite places as destinations.

# %%
places = gpd.read_file(PLACES_PATH)
assert places.crs.to_epsg() == 4326

home = places[places["category"] == "home_origin"].copy()
destinations = places[places["category"] != "home_origin"].copy()

print(places["category"].value_counts())
places.head()
# Out:
# category
# favorite_place    27
# friends_home       5
# home_origin        1
# Name: count, dtype: int64
#                        name      category               privacy     precision  \
# 0  Home — relational origin   home_origin  approximate_location  neighborhood
# 1           Friend's home 1  friends_home  approximate_location  neighborhood
# 2           Friend's home 2  friends_home  approximate_location  neighborhood
# 3           Friend's home 3  friends_home  approximate_location  neighborhood
# 4           Friend's home 4  friends_home  approximate_location  neighborhood
#
#   subcategory verification                geometry
# 0         NaN          NaN  POINT (9.2362 45.4792)
# 1         NaN          NaN  POINT (9.2322 45.4689)
# 2         NaN          NaN  POINT (9.2251 45.4652)
# 3         NaN          NaN   POINT (9.2167 45.484)
# 4         NaN          NaN  POINT (9.2232 45.4704)

# %%
from matplotlib import font_manager
from pathlib import Path

FONT_PATH = (
    Path("..") / "assets" / "fonts" / "CascadiaCode" / "CascadiaCode.ttf"
).resolve()
font_manager.fontManager.addfont(str(FONT_PATH))
cascadia = font_manager.FontProperties(fname=str(FONT_PATH))
plt.rcParams["font.family"] = cascadia.get_name()

ELECTRIC_BLUE = "#1100FF"
FUCHSIA = "#FF00FF"

favorites = places[places["category"] == "favorite_place"]
friends = places[places["category"] == "friends_home"]

fig, ax = plt.subplots(figsize=(9, 9))

favorites.plot(
    ax=ax,
    color=ELECTRIC_BLUE,
    markersize=50,
    marker="+",
    linewidth=0.75,
    label="My Places",
    zorder=3,
)
friends.plot(
    ax=ax,
    color=FUCHSIA,
    markersize=50,
    marker="+",
    linewidth=0.75,
    label="My People",
    zorder=4,
)
# Home: hollow square with electric-blue border only
ax.scatter(
    home.geometry.x,
    home.geometry.y,
    s=50,
    marker="s",
    facecolors="none",
    edgecolors=ELECTRIC_BLUE,
    linewidths=0.75,
    label="home",
    zorder=5,
)

# Geographic coordinates next to every point
for _idx, row in places.iterrows():
    ax.annotate(
        f"{row.geometry.x:.4f}, {row.geometry.y:.4f}",
        xy=(row.geometry.x, row.geometry.y),
        xytext=(5, 5),
        textcoords="offset points",
        fontsize=5,
        fontproperties=cascadia,
        color="#222222",
    )

legend = ax.legend(loc="upper left", frameon=True, prop=cascadia)
ax.set_title(
    "Nodes of interest: my affective Milan", fontproperties=cascadia, fontsize=9
)
plt.show()

# %% [markdown]
# ## 3. Build the bicycle street network (OSMnx)
#
# Following the tutorial's street-graph pattern, we download the **bike** network for a bounding box that covers all personal places (with a small buffer). Edges become traversable street segments; graph nodes are intersections.
#
# > First run needs internet access and may take a minute; OSMnx caches the download for later runs.

# %%
# Buffer the places bbox slightly so routes near the edge stay connected
minx, miny, maxx, maxy = places.total_bounds
pad = 0.012  # ~1 km in lon/lat at Milan latitude
bbox = (minx - pad, miny - pad, maxx + pad, maxy + pad)  # west, south, east, north

print("Downloading bicycle network for bbox:", bbox)
bike_network = ox.graph_from_bbox(bbox=bbox, network_type="bike")
bike_network = ox.add_edge_speeds(bike_network)
bike_network = ox.add_edge_travel_times(bike_network)

net_nodes, net_edges = ox.graph_to_gdfs(bike_network)
print(f"Nodes: {len(net_nodes):,} | Edges: {len(net_edges):,}")
# Out:
# Downloading bicycle network for bbox: (np.float64(9.161543799999999), np.float64(45.4320969), np.float64(9.298076), np.float64(45.5241363))
# Nodes: 19,341 | Edges: 40,693

# %%
from matplotlib import font_manager
from pathlib import Path

FONT_PATH = (
    Path("..") / "assets" / "fonts" / "CascadiaCode" / "CascadiaCode.ttf"
).resolve()
font_manager.fontManager.addfont(str(FONT_PATH))
cascadia = font_manager.FontProperties(fname=str(FONT_PATH))
plt.rcParams["font.family"] = cascadia.get_name()

ELECTRIC_BLUE = "#675DFF"
FUCHSIA = "#FF9FFF"

favorites = places[places["category"] == "favorite_place"]
friends = places[places["category"] == "friends_home"]

fig, ax = plt.subplots(figsize=(9, 9), facecolor="#1F0C49")
ax.set_facecolor("#1F0C49")

# White street network on dark background
net_edges.plot(ax=ax, color="white", linewidth=0.15, alpha=0.65, zorder=1)

favorites.plot(
    ax=ax,
    color=ELECTRIC_BLUE,
    markersize=50,
    marker="+",
    linewidth=1,
    label="My Places",
    zorder=3,
)
friends.plot(
    ax=ax,
    color=FUCHSIA,
    markersize=50,
    marker="+",
    linewidth=1,
    label="My People",
    zorder=4,
)
ax.scatter(
    home.geometry.x,
    home.geometry.y,
    s=50,
    marker="s",
    facecolors="none",
    edgecolors=ELECTRIC_BLUE,
    linewidths=0.75,
    label="home",
    zorder=5,
)

# Geographic coordinates in Cascadia, white
for _idx, row in places.iterrows():
    ax.annotate(
        f"{row.geometry.x:.4f}, {row.geometry.y:.4f}",
        xy=(row.geometry.x, row.geometry.y),
        xytext=(5, 5),
        textcoords="offset points",
        fontsize=5,
        fontproperties=cascadia,
        color="white",
    )

legend = ax.legend(
    loc="upper left",
    frameon=True,
    prop=cascadia,
    facecolor="#1F0C49",
    edgecolor="white",
    labelcolor="white",
)
ax.set_title(
    "OSM bicycle network + personal places",
    fontproperties=cascadia,
    fontsize=9,
    color="white",
)
for spine in ax.spines.values():
    spine.set_color("white")
plt.show()

# %% [markdown]
# ## 4. Snap places to the network
#
# As in the tutorial: associate each geographic point with the **nearest graph node** before computing shortest paths.

# %%
home_node = ox.distance.nearest_nodes(
    bike_network, home.geometry.x.iloc[0], home.geometry.y.iloc[0]
)

destinations = destinations.copy()
destinations["net_node"] = ox.distance.nearest_nodes(
    bike_network, destinations.geometry.x, destinations.geometry.y
)

print("Home network node:", home_node)
destinations[["name", "category", "net_node"]].head()
# Out:
# Home network node: 6919857056
#               name      category    net_node
# 1  Friend's home 1  friends_home  3696911821
# 2  Friend's home 2  friends_home    29765455
# 3  Friend's home 3  friends_home   306377053
# 4  Friend's home 4  friends_home   442095658
# 5  Friend's home 5  friends_home   250154658

# %% [markdown]
# ## 5. Euclidean vs network distance
#
# For each destination we compute:
#
# - **Euclidean distance** — straight-line distance in meters (`EPSG:32632`).
# - **Network distance** — shortest path along the bike graph, weighted by edge `length` (tutorial method: `ox.shortest_path` + `ox.routing.route_to_gdf`).
# - **Detour ratio** — network / Euclidean (values > 1 mean the street network forces a longer trip than "as the crow flies").

# %%
places_m = places.to_crs(32632)
home_m = places_m[places_m["category"] == "home_origin"].geometry.iloc[0]


def network_route_from_home(row, graph, origin_node):
    dest_node = int(row["net_node"])
    route = ox.shortest_path(graph, origin_node, dest_node, weight="length")
    if route is None or len(route) < 2:
        return {
            "network_m": np.nan,
            "route_geom": None,
            "n_edges": 0,
        }
    route_gdf = ox.routing.route_to_gdf(graph, route)
    return {
        "network_m": float(route_gdf["length"].sum()),
        "route_geom": route_gdf.geometry.union_all(),
        "n_edges": len(route_gdf),
    }


# Euclidean distance in projected meters
dest_m = destinations.to_crs(32632)
destinations["euclidean_m"] = dest_m.geometry.distance(home_m)

# Network distance + route geometry
route_info = destinations.apply(
    network_route_from_home, graph=bike_network, origin_node=home_node, axis=1
)
destinations = pd.concat([destinations, route_info.apply(pd.Series)], axis=1)

destinations["detour_ratio"] = destinations["network_m"] / destinations["euclidean_m"]
destinations["euclidean_km"] = destinations["euclidean_m"] / 1000
destinations["network_km"] = destinations["network_m"] / 1000

results = destinations[
    [
        "name",
        "category",
        "subcategory",
        "euclidean_km",
        "network_km",
        "detour_ratio",
        "n_edges",
        "geometry",
        "route_geom",
    ]
].sort_values("network_km")

results.head(10)
# Out:
#                         name        category            subcategory  \
# 19                Il Bancale  favorite_place                    bar
# 13       Politecnico — Patio  favorite_place             university
# 20  Piazza Leonardo da Vinci  favorite_place           public_space
# 1            Friend's home 1    friends_home                    NaN
# 24                 Bar Basso  favorite_place                    bar
# 7        Caffè degli Artisti  favorite_place                    bar
# 10     La Balera dell'Ortica  favorite_place  music_and_social_life
# 4            Friend's home 4    friends_home                    NaN
# 3            Friend's home 3    friends_home                    NaN
# 8            La Belle Aurore  favorite_place                    bar
#
#     euclidean_km  network_km  detour_ratio  n_edges                  geometry  \
# 19      0.215386    0.429129      1.992375        6  POINT (9.23417 45.48051)
# 13      0.734798    1.062391      1.445827       12  POINT (9.22681 45.47953)
# 20      0.898339    1.436111      1.598628       22   POINT (9.2248 45.47814)
# 1       1.186243    1.646573      1.388057       20    POINT (9.2322 45.4689)
# 24      1.480090    1.878104      1.268912       32  POINT (9.21758 45.47677)
# 7       1.531626    1.933191      1.262182       35  POINT (9.21682 45.47715)
# 10      1.066787    1.963898      1.840947       27   POINT (9.2403 45.47004)
# 4       1.410063    2.019080      1.431907       26    POINT (9.2232 45.4704)
# 3       1.614581    2.030469      1.257583       31     POINT (9.2167 45.484)
# 8       1.877879    2.225011      1.184854       36  POINT (9.21451 45.47193)
#
#                                            route_geom
# 19  MULTILINESTRING ((9.2366095 45.4793854, 9.2366...
# 13  MULTILINESTRING ((9.2366095 45.4793854, 9.2366...
# 20  MULTILINESTRING ((9.2366095 45.4793854, 9.2366...
# 1   MULTILINESTRING ((9.2366095 45.4793854, 9.2366...
# 24  MULTILINESTRING ((9.2366095 45.4793854, 9.2366...
# 7   MULTILINESTRING ((9.2366095 45.4793854, 9.2366...
# 10  MULTILINESTRING ((9.2366095 45.4793854, 9.2366...
# 4   MULTILINESTRING ((9.2366095 45.4793854, 9.2366...
# 3   MULTILINESTRING ((9.2366095 45.4793854, 9.2366...
# 8   MULTILINESTRING ((9.2366095 45.4793854, 9.2366...

# %% [markdown]
# ### Summary table

# %%
summary = results[
    ["name", "category", "euclidean_km", "network_km", "detour_ratio"]
].copy()
summary["euclidean_km"] = summary["euclidean_km"].round(2)
summary["network_km"] = summary["network_km"].round(2)
summary["detour_ratio"] = summary["detour_ratio"].round(2)
summary
# Out:
#                           name        category  euclidean_km  network_km  \
# 19                  Il Bancale  favorite_place          0.22        0.43
# 13         Politecnico — Patio  favorite_place          0.73        1.06
# 20    Piazza Leonardo da Vinci  favorite_place          0.90        1.44
# 1              Friend's home 1    friends_home          1.19        1.65
# 24                   Bar Basso  favorite_place          1.48        1.88
# 7          Caffè degli Artisti  favorite_place          1.53        1.93
# 10       La Balera dell'Ortica  favorite_place          1.07        1.96
# 4              Friend's home 4    friends_home          1.41        2.02
# 3              Friend's home 3    friends_home          1.61        2.03
# 8              La Belle Aurore  favorite_place          1.88        2.23
# 30                 Pacino Café  favorite_place          1.43        2.27
# 32              Piccola Ischia  favorite_place          1.50        2.37
# 2              Friend's home 2    friends_home          1.78        2.44
# 16          Consorzio Stoppani  favorite_place          1.80        2.63
# 25                      Magutt  favorite_place          2.14        2.86
# 21                     Égalité  favorite_place          2.18        2.86
# 23                Bar L'Angolo  favorite_place          2.28        2.86
# 6                  Bar Picchio  favorite_place          2.26        3.02
# 29          Via Mauro Macchi 6  favorite_place          2.51        3.19
# 15                 Tunnel Club  favorite_place          2.57        3.41
# 9    Giardini Indro Montanelli  favorite_place          2.85        3.43
# 12             Viale Molise 69  favorite_place          2.67        3.48
# 5              Friend's home 5    friends_home          2.59        3.66
# 11                    MOM Café  favorite_place          3.25        4.23
# 31        Pizzeria Santa Maria  favorite_place          3.74        5.00
# 26              Parco Sempione  favorite_place          4.68        5.77
# 27          Castello Sforzesco  favorite_place          4.65        5.94
# 28            Triennale Milano  favorite_place          4.97        6.16
# 14          Magazzini Generali  favorite_place          5.05        6.43
# 22      Colonne di San Lorenzo  favorite_place          4.90        6.52
# 18  Aeroporto di Milano Linate  favorite_place          5.07        6.75
# 17            Circolo Magnolia  favorite_place          4.26        8.65
#
#     detour_ratio
# 19          1.99
# 13          1.45
# 20          1.60
# 1           1.39
# 24          1.27
# 7           1.26
# 10          1.84
# 4           1.43
# 3           1.26
# 8           1.18
# 30          1.59
# 32          1.58
# 2           1.37
# 16          1.46
# 25          1.33
# 21          1.31
# 23          1.25
# 6           1.33
# 29          1.27
# 15          1.32
# 9           1.21
# 12          1.30
# 5           1.42
# 11          1.30
# 31          1.33
# 26          1.23
# 27          1.28
# 28          1.24
# 14          1.28
# 22          1.33
# 18          1.33
# 17          2.03

# %% [markdown]
# ## 6. Maps
#
# ### 6.1 Shortest bicycle routes from home

# %%
from matplotlib import font_manager
from pathlib import Path

FONT_PATH = (
    Path("..") / "assets" / "fonts" / "CascadiaCode" / "CascadiaCode.ttf"
).resolve()
font_manager.fontManager.addfont(str(FONT_PATH))
cascadia = font_manager.FontProperties(fname=str(FONT_PATH))
plt.rcParams["font.family"] = cascadia.get_name()

ELECTRIC_BLUE = "#675DFF"
FUCHSIA = "#FF9FFF"
BG = "#1F0C49"
CAT_COLORS = {"favorite_place": ELECTRIC_BLUE, "friends_home": FUCHSIA}

routes_gdf = gpd.GeoDataFrame(
    results.dropna(subset=["route_geom"]).copy(),
    geometry="route_geom",
    crs="EPSG:4326",
)

favorites = places[places["category"] == "favorite_place"]
friends = places[places["category"] == "friends_home"]

fig, ax = plt.subplots(figsize=(10, 10), facecolor=BG)
ax.set_facecolor(BG)

# White street network on dark background
net_edges.plot(ax=ax, color="white", linewidth=0.15, alpha=0.65, zorder=1)

# Routes colored by category (same palette as previous map)
for cat, color in CAT_COLORS.items():
    subset = routes_gdf[routes_gdf["category"] == cat]
    if len(subset):
        subset.plot(ax=ax, color=color, linewidth=1.6, alpha=0.9, zorder=2)

favorites.plot(
    ax=ax,
    color=ELECTRIC_BLUE,
    markersize=50,
    marker="+",
    linewidth=1,
    label="My Places",
    zorder=3,
)
friends.plot(
    ax=ax,
    color=FUCHSIA,
    markersize=50,
    marker="+",
    linewidth=1,
    label="My People",
    zorder=4,
)
ax.scatter(
    home.geometry.x,
    home.geometry.y,
    s=50,
    marker="s",
    facecolors=ELECTRIC_BLUE,
    edgecolors=ELECTRIC_BLUE,
    linewidths=0.75,
    label="home",
    zorder=5,
)

# Geographic coordinates in Cascadia, white
for _idx, row in places.iterrows():
    ax.annotate(
        f"{row.geometry.x:.4f}, {row.geometry.y:.4f}",
        xy=(row.geometry.x, row.geometry.y),
        xytext=(5, 5),
        textcoords="offset points",
        fontsize=5,
        fontproperties=cascadia,
        color="white",
    )

legend = ax.legend(
    loc="upper left",
    frameon=True,
    prop=cascadia,
    facecolor=BG,
    edgecolor="white",
    labelcolor="white",
)
ax.set_title(
    "Shortest bicycle routes from home",
    fontproperties=cascadia,
    fontsize=9,
    color="white",
)
for spine in ax.spines.values():
    spine.set_color("white")
plt.show()

# %% [markdown]
# ### 6.2 One destination: Euclidean line vs network path
#
# Pick the destination with the highest detour ratio to make the experiential gap visible.

# %%
from matplotlib import font_manager
from pathlib import Path

FONT_PATH = (
    Path("..") / "assets" / "fonts" / "CascadiaCode" / "CascadiaCode.ttf"
).resolve()
font_manager.fontManager.addfont(str(FONT_PATH))
cascadia = font_manager.FontProperties(fname=str(FONT_PATH))
plt.rcParams["font.family"] = cascadia.get_name()

ELECTRIC_BLUE = "#675DFF"
FUCHSIA = "#FF9FFF"
PERIWINKLE = "#B8B0FF"  # Euclidean desire-line (same family, lighter)
BG = "#1F0C49"
CAT_COLORS = {"favorite_place": ELECTRIC_BLUE, "friends_home": FUCHSIA}

# Highest detour among reachable destinations
focus = (
    results.dropna(subset=["route_geom"])
    .sort_values("detour_ratio", ascending=False)
    .iloc[0]
)
home_pt = home.geometry.iloc[0]
dest_pt = focus.geometry
route_color = CAT_COLORS.get(focus["category"], ELECTRIC_BLUE)

eucl_line = gpd.GeoDataFrame(geometry=[LineString([home_pt, dest_pt])], crs="EPSG:4326")
route_line = gpd.GeoDataFrame(geometry=[focus.route_geom], crs="EPSG:4326")

fig, ax = plt.subplots(figsize=(9, 9), facecolor=BG)
ax.set_facecolor(BG)

pad_m = 0.008
xs = [home_pt.x, dest_pt.x]
ys = [home_pt.y, dest_pt.y]
ax.set_xlim(min(xs) - pad_m, max(xs) + pad_m)
ax.set_ylim(min(ys) - pad_m, max(ys) + pad_m)

net_edges.plot(ax=ax, color="white", linewidth=0.2, alpha=0.55, zorder=1)
eucl_line.plot(
    ax=ax,
    color=PERIWINKLE,
    linewidth=2.0,
    linestyle=":",
    label="Euclidean",
    zorder=3,
)
route_line.plot(
    ax=ax, color=route_color, linewidth=2.4, label="Network (bike)", zorder=4
)

ax.scatter(
    [home_pt.x],
    [home_pt.y],
    s=70,
    marker="s",
    facecolors=ELECTRIC_BLUE,
    edgecolors=ELECTRIC_BLUE,
    linewidths=0.75,
    label="home",
    zorder=5,
)
ax.plot(
    dest_pt.x,
    dest_pt.y,
    marker="+",
    markersize=12,
    markeredgewidth=1.5,
    color=route_color,
    linestyle="None",
    label=focus["name"],
    zorder=6,
)

for pt in (home_pt, dest_pt):
    ax.annotate(
        f"{pt.x:.4f}, {pt.y:.4f}",
        xy=(pt.x, pt.y),
        xytext=(5, 5),
        textcoords="offset points",
        fontsize=5,
        fontproperties=cascadia,
        color="white",
    )

legend = ax.legend(
    loc="best",
    frameon=True,
    prop=cascadia,
    facecolor=BG,
    edgecolor="white",
    labelcolor="white",
    fontsize=7,
)
ax.set_title(
    f"{focus['name']}\n"
    f"Euclidean {focus['euclidean_km']:.2f} km | "
    f"Network {focus['network_km']:.2f} km | "
    f"detour x{focus['detour_ratio']:.2f}",
    fontproperties=cascadia,
    fontsize=8,
    color="white",
)
for spine in ax.spines.values():
    spine.set_color("white")
plt.show()

# %% [markdown]
# ## 7. Charts

# %%
from matplotlib import font_manager
from pathlib import Path
from matplotlib.lines import Line2D

FONT_PATH = (
    Path("..") / "assets" / "fonts" / "CascadiaCode" / "CascadiaCode.ttf"
).resolve()
font_manager.fontManager.addfont(str(FONT_PATH))
cascadia = font_manager.FontProperties(fname=str(FONT_PATH))
plt.rcParams["font.family"] = cascadia.get_name()

ELECTRIC_BLUE = "#675DFF"
FUCHSIA = "#FF9FFF"
BG = "#1F0C49"
CAT_COLORS = {"favorite_place": ELECTRIC_BLUE, "friends_home": FUCHSIA}

fig, ax = plt.subplots(figsize=(7, 7), facecolor=BG)
ax.set_facecolor(BG)

colors = results["category"].map(CAT_COLORS)
ax.scatter(
    results["euclidean_km"],
    results["network_km"],
    c=colors,
    s=55,
    marker="+",
    linewidths=1.2,
    zorder=3,
)
lim = max(results["euclidean_km"].max(), results["network_km"].max()) * 1.05
ax.plot(
    [0, lim],
    [0, lim],
    color="#B8B0FF",
    linestyle=":",
    linewidth=1.2,
    label="equal distance",
    zorder=2,
)

ax.set_xlabel("Euclidean distance (km)", fontproperties=cascadia, color="white")
ax.set_ylabel("Network (bike) distance (km)", fontproperties=cascadia, color="white")
ax.set_title(
    "Euclidean vs network distance from home",
    fontproperties=cascadia,
    fontsize=9,
    color="white",
)
ax.set_aspect("equal", adjustable="box")
ax.tick_params(colors="white")
for spine in ax.spines.values():
    spine.set_color("white")

legend_handles = [
    Line2D(
        [0],
        [0],
        marker="+",
        color="none",
        markeredgecolor=ELECTRIC_BLUE,
        markerfacecolor=ELECTRIC_BLUE,
        markersize=10,
        label="My Places",
    ),
    Line2D(
        [0],
        [0],
        marker="+",
        color="none",
        markeredgecolor=FUCHSIA,
        markerfacecolor=FUCHSIA,
        markersize=10,
        label="My People",
    ),
    Line2D(
        [0], [0], color="#B8B0FF", linestyle=":", linewidth=1.2, label="equal distance"
    ),
]
legend = ax.legend(
    handles=legend_handles,
    loc="upper left",
    frameon=True,
    prop=cascadia,
    facecolor=BG,
    edgecolor="white",
    labelcolor="white",
)
plt.show()

# %%
from matplotlib import font_manager
from pathlib import Path

FONT_PATH = (
    Path("..") / "assets" / "fonts" / "CascadiaCode" / "CascadiaCode.ttf"
).resolve()
font_manager.fontManager.addfont(str(FONT_PATH))
cascadia = font_manager.FontProperties(fname=str(FONT_PATH))
plt.rcParams["font.family"] = cascadia.get_name()

ELECTRIC_BLUE = "#675DFF"
FUCHSIA = "#FF9FFF"
BG = "#1F0C49"
CAT_COLORS = {"favorite_place": ELECTRIC_BLUE, "friends_home": FUCHSIA}

fig, ax = plt.subplots(figsize=(8, 5.5), facecolor=BG)
ax.set_facecolor(BG)

plot_df = results.sort_values("detour_ratio")
ax.barh(
    plot_df["name"],
    plot_df["detour_ratio"],
    color=plot_df["category"].map(CAT_COLORS),
    edgecolor="none",
    height=0.7,
)
ax.axvline(1.0, color="#B8B0FF", linestyle=":", linewidth=1.2)

ax.set_xlabel(
    "Detour ratio (network / Euclidean)", fontproperties=cascadia, color="white"
)
ax.set_title(
    "How much farther is the bike route than the straight line?",
    fontproperties=cascadia,
    fontsize=9,
    color="white",
)
ax.tick_params(colors="white", labelsize=7)
for label in ax.get_yticklabels():
    label.set_fontproperties(cascadia)
for spine in ax.spines.values():
    spine.set_color("white")
plt.tight_layout()
plt.show()

# %%
print("Mean detour ratio:", round(results["detour_ratio"].mean(), 2))
print("Median detour ratio:", round(results["detour_ratio"].median(), 2))
print(
    "Max detour:",
    results.loc[results["detour_ratio"].idxmax(), "name"],
    round(results["detour_ratio"].max(), 2),
)
print(
    "Min detour:",
    results.loc[results["detour_ratio"].idxmin(), "name"],
    round(results["detour_ratio"].min(), 2),
)
# Out:
# Mean detour ratio: 1.4
# Median detour ratio: 1.33
# Max detour: Circolo Magnolia 2.03
# Min detour: La Belle Aurore 1.18

# %% [markdown]
# ## 8. Bike reach from home (tutorial isochrone pattern)
#
# The tutorial builds walking isochrones with `nx.ego_graph` and travel time. Below we sketch approximate **5 / 10 / 15 minute** bicycle reach from home.

# %%
from matplotlib import font_manager
from pathlib import Path

FONT_PATH = (
    Path("..") / "assets" / "fonts" / "CascadiaCode" / "CascadiaCode.ttf"
).resolve()
font_manager.fontManager.addfont(str(FONT_PATH))
cascadia = font_manager.FontProperties(fname=str(FONT_PATH))
plt.rcParams["font.family"] = cascadia.get_name()

ELECTRIC_BLUE = "#675DFF"
FUCHSIA = "#FF9FFF"
PERIWINKLE = "#B8B0FF"
BG = "#1F0C49"

trip_minutes = [5, 10, 15]
# Palette-aligned isochrone colors (near -> far)
iso_palette = {
    5: FUCHSIA,
    10: PERIWINKLE,
    15: ELECTRIC_BLUE,
}

for _u, _v, _k, data in bike_network.edges(keys=True, data=True):
    # travel_time from OSMnx is in seconds; fallback ~15 km/h if missing
    data["time_min"] = data.get("travel_time", data["length"] / 4.1667) / 60

node_colors = {}
for trip_time in sorted(trip_minutes, reverse=True):
    subgraph = nx.ego_graph(
        bike_network, home_node, radius=trip_time, distance="time_min"
    )
    for node in subgraph.nodes():
        node_colors[node] = iso_palette[trip_time]

nc = [node_colors.get(n, "none") for n in bike_network.nodes()]
ns = [3 if n in node_colors else 0 for n in bike_network.nodes()]

fig, ax = ox.plot_graph(
    bike_network,
    node_color=nc,
    node_size=ns,
    node_alpha=0.9,
    edge_linewidth=0.25,
    edge_color="white",
    edge_alpha=0.35,
    bgcolor=BG,
    show=False,
    close=False,
)
fig.patch.set_facecolor(BG)
ax.set_facecolor(BG)

ax.scatter(
    home.geometry.x,
    home.geometry.y,
    s=70,
    marker="s",
    facecolors=ELECTRIC_BLUE,
    edgecolors=ELECTRIC_BLUE,
    linewidths=0.75,
    zorder=5,
    label="home",
)

ax.set_title(
    "Bike reach from home (approx. 5 / 10 / 15 minutes)",
    fontproperties=cascadia,
    fontsize=9,
    color="white",
)
for spine in ax.spines.values():
    spine.set_color("white")
plt.show()

# %% [markdown]
# ## 9. Reflection
#
# ### What the network shows
#
# - Euclidean distance answers: *how far is this place if I could cut through buildings and rivers?*
# - Network distance answers: *how far is this place if I actually cycle on streets that exist?*
#
# Where the **detour ratio** is high, the city fabric forces me to travel farther than the map's straight line suggests — canals, rail corridors, one-way patterns, or sparse cycle links. Where it is close to 1, the street grid aligns well with my desire line from home.
#
# ### Experiential difference
#
# On a bike, "closeness" is not only meters: it is also continuity of cycling infrastructure, sense of safety, and whether a route feels like a shortcut through a familiar neighborhood. Two destinations with similar Euclidean distance can feel very different if one sits on a direct cycle route and the other requires a long diversion.
#
# ### Next steps (optional)
#
# - Intersect routes with the Comune di Milano *Itinerari ciclabili* layer (Assignment 02) to measure % of each trip on official cycling infrastructure.
# - Compare `network_type="bike"` vs `"walk"` or `"drive"` for the same origin–destination pairs.
# - Add travel-time weights that reflect perceived effort (hills, traffic) rather than length alone.
