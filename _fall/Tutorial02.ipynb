# %%
import geopandas as gpd
import mapclassify
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import geopandas as gpd
# ----> 2 import mapclassify
#       3 import matplotlib.pyplot as plt
#       4 import numpy as np
#       5 import pandas as pd
#
# File /opt/miniconda3/envs/cdp/lib/python3.14/site-packages/mapclassify/__init__.py:4
#       1 import contextlib
#       2 from importlib.metadata import PackageNotFoundError, version
# ----> 4 from . import legendgram, util
#       5 from ._classify_API import classify
#       6 from .classifiers import (
#       7     CLASSIFIERS,
#       8     BoxPlot,
#    (...)     26     load_example,
#      27 )
#
# File /opt/miniconda3/envs/cdp/lib/python3.14/site-packages/mapclassify/util.py:3
#       1 import numpy as np
# ----> 3 from ._classify_API import classify as _classify
#       6 def get_color_array(
#       7     values,
# ...
